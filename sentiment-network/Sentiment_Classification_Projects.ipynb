# %% [markdown]
# # Sentiment Classification & How To "Frame Problems" for a Neural Network
#
# by Andrew Trask
#
# - **Twitter**: @iamtrask
# - **Blog**: http://iamtrask.github.io

# %% [markdown]
# ### What You Should Already Know
#
# - neural networks, forward and back-propagation
# - stochastic gradient descent
# - mean squared error
# - and train/test splits
#
# ### Where to Get Help if You Need it
# - Re-watch previous Udacity Lectures
# - Leverage the recommended Course Reading Material - [Grokking Deep Learning](https://www.manning.com/books/grokking-deep-learning) (Check inside your classroom for a discount code)
# - Shoot me a tweet @iamtrask
#
#
# ### Tutorial Outline:
#
# - Intro: The Importance of "Framing a Problem" (this lesson)
#
# - [Curate a Dataset](#lesson_1)
# - [Developing a "Predictive Theory"](#lesson_2)
# - [**PROJECT 1**: Quick Theory Validation](#project_1)
#
#
# - [Transforming Text to Numbers](#lesson_3)
# - [**PROJECT 2**: Creating the Input/Output Data](#project_2)
#
#
# - Putting it all together in a Neural Network (video only - nothing in notebook)
# - [**PROJECT 3**: Building our Neural Network](#project_3)
#
#
# - [Understanding Neural Noise](#lesson_4)
# - [**PROJECT 4**: Making Learning Faster by Reducing Noise](#project_4)
#
#
# - [Analyzing Inefficiencies in our Network](#lesson_5)
# - [**PROJECT 5**: Making our Network Train and Run Faster](#project_5)
#
#
# - [Further Noise Reduction](#lesson_6)
# - [**PROJECT 6**: Reducing Noise by Strategically Reducing the Vocabulary](#project_6)
#
#
# - [Analysis: What's going on in the weights?](#lesson_7)

# %% [markdown]
# # Lesson: Curate a Dataset<a id='lesson_1'></a>
# The cells from here until Project 1 include code Andrew shows in the videos leading up to mini project 1. We've included them so you can run the code along with the videos without having to type in everything.

# %%
def pretty_print_review_and_label(i):
    print(labels[i] + "\t:\t" + reviews[i][:80] + "...")

g = open('reviews.txt','r') # What we know!
reviews = list(map(lambda x:x[:-1],g.readlines()))
g.close()

g = open('labels.txt','r') # What we WANT to know!
labels = list(map(lambda x:x[:-1].upper(),g.readlines()))
g.close()

# %% [markdown]
# **Note:** The data in `reviews.txt` we're using has already been preprocessed a bit and contains only lower case characters. If we were working from raw data, where we didn't know it was all lower case, we would want to add a step here to convert it. That's so we treat different variations of the same word, like `The`, `the`, and `THE`, all the same way.

# %%
len(reviews)
# Out:
# 25000

# %%
reviews[0]
# Out:
# 'bromwell high is a cartoon comedy . it ran at the same time as some other programs about school life  such as  teachers  . my   years in the teaching profession lead me to believe that bromwell high  s satire is much closer to reality than is  teachers  . the scramble to survive financially  the insightful students who can see right through their pathetic teachers  pomp  the pettiness of the whole situation  all remind me of the schools i knew and their students . when i saw the episode in which a student repeatedly tried to burn down the school  i immediately recalled . . . . . . . . . at . . . . . . . . . . high . a classic line inspector i  m here to sack one of your teachers . student welcome to bromwell high . i expect that many adults of my age think that bromwell high is far fetched . what a pity that it isn  t   '

# %%
labels[0]
# Out:
# 'POSITIVE'

# %% [markdown]
# # Lesson: Develop a Predictive Theory<a id='lesson_2'></a>

# %%
print("labels.txt \t : \t reviews.txt\n")
pretty_print_review_and_label(2137)
pretty_print_review_and_label(12816)
pretty_print_review_and_label(6267)
pretty_print_review_and_label(21934)
pretty_print_review_and_label(5297)
pretty_print_review_and_label(4998)
# Out:
# labels.txt 	 : 	 reviews.txt
#
# NEGATIVE	:	this movie is terrible but it has some good effects .  ...
# POSITIVE	:	adrian pasdar is excellent is this film . he makes a fascinating woman .  ...
# NEGATIVE	:	comment this movie is impossible . is terrible  very improbable  bad interpretat...
# POSITIVE	:	excellent episode movie ala pulp fiction .  days   suicides . it doesnt get more...
# NEGATIVE	:	if you haven  t seen this  it  s terrible . it is pure trash . i saw this about ...
# POSITIVE	:	this schiffer guy is a real genius  the movie is of excellent quality and both e...

# %% [markdown]
# # Project 1: Quick Theory Validation<a id='project_1'></a>
#
# There are multiple ways to implement these projects, but in order to get your code closer to what Andrew shows in his solutions, we've provided some hints and starter code throughout this notebook.
#
# You'll find the [Counter](https://docs.python.org/2/library/collections.html#collections.Counter) class to be useful in this exercise, as well as the [numpy](https://docs.scipy.org/doc/numpy/reference/) library.

# %%
from collections import Counter
import numpy as np

# %% [markdown]
# We'll create three `Counter` objects, one for words from postive reviews, one for words from negative reviews, and one for all the words.

# %%
# Create three Counter objects to store positive, negative and total counts
positive_counts = Counter()
negative_counts = Counter()
total_counts = Counter()

# %% [markdown]
# **TODO:** Examine all the reviews. For each word in a positive review, increase the count for that word in both your positive counter and the total words counter; likewise, for each word in a negative review, increase the count for that word in both your negative counter and the total words counter.
#
# **Note:** Throughout these projects, you should use `split(' ')` to divide a piece of text (such as a review) into individual words. If you use `split()` instead, you'll get slightly different results than what the videos and solutions show.

# %%
# TODO: Loop over all the words in all the reviews and increment the counts in the appropriate counter objects
sum_pos = 0
sum_neg = 0
for r in range(len(reviews)):
    if(labels[r] == "POSITIVE"):
        sum_pos = sum_pos + 1;
        
        for w in reviews[r].split(" "):
            positive_counts[w] += 1
            total_counts[w] += 1
    else:
        sum_neg = sum_neg + 1;
        
        for w in reviews[r].split(" "):
            negative_counts[w] += 1
            total_counts[w] += 1
        
        
#    if( sum_pos > 2):
#        break;

print("positive reviews", sum_pos)
print("negative reviews", sum_neg)

print(positive_counts)
# Out:
# positive reviews 12500
# negative reviews 12500
# Counter({'': 550583, 'the': 173367, '.': 159704, 'and': 89731, 'a': 83715, 'of': 76866, 'to': 66774, 'is': 57256, 'in': 50221, 'br': 49243, 'it': 48036, 'i': 40752, 'that': 35636, 'this': 35082, 's': 33824, 'as': 26318, 'with': 23251, 'for': 22422, 'was': 21917, 'film': 20938, 'but': 20824, 'movie': 19075, 'his': 17233, 'on': 17020, 'you': 16685, 'he': 16290, 'are': 14810, 'not': 14273, 't': 13725, 'one': 13658, 'have': 12588, 'be': 12420, 'by': 12000, 'all': 11945, 'who': 11472, 'an': 11296, 'at': 11236, 'from': 10770, 'her': 10476, 'they': 9899, 'has': 9188, 'so': 9154, 'like': 9043, 'about': 8315, 'very': 8305, 'out': 8135, 'there': 8057, 'she': 7779, 'what': 7743, 'or': 7740, 'good': 7721, 'more': 7523, 'when': 7459, 'some': 7442, 'if': 7289, 'just': 7153, 'can': 7005, 'story': 6780, 'time': 6518, 'my': 6490, 'great': 6419, 'well': 6405, 'up': 6322, 'which': 6269, 'their': 6110, 'see': 6030, 'also': 5551, 'we': 5531, 'really': 5476, 'would': 5400, 'will': 5219, 'me': 5169, 'had': 5149, 'only': 5137, 'him': 5018, 'even': 4964, 'most': 4865, 'other': 4861, 'were': 4784, 'first': 4755, 'than': 4738, 'much': 4686, 'its': 4622, 'no': 4574, 'into': 4544, 'people': 4481, 'best': 4320, 'love': 4303, 'get': 4272, 'how': 4213, 'life': 4201, 'been': 4190, 'because': 4079, 'way': 4036, 'do': 3944, 'made': 3823, 'films': 3814, 'them': 3805, 'after': 3802, 'many': 3767, 'two': 3734, 'too': 3660, 'think': 3657, 'movies': 3586, 'characters': 3561, 'character': 3515, 'don': 3469, 'man': 3461, 'show': 3434, 'watch': 3424, 'seen': 3415, 'then': 3358, 'little': 3341, 'still': 3340, 'make': 3304, 'could': 3237, 'never': 3227, 'being': 3222, 'where': 3179, 'does': 3069, 'over': 3018, 'any': 3002, 'while': 2901, 'know': 2834, 'did': 2792, 'years': 2760, 'here': 2742, 'ever': 2735, 'end': 2697, 'these': 2694, 'such': 2593, 'scene': 2570, 'real': 2568, 'back': 2547, 'those': 2486, 'though': 2475, 'off': 2464, 'new': 2458, 'your': 2454, 'go': 2440, 'acting': 2438, 'plot': 2433, 'world': 2430, 'scenes': 2428, 'say': 2414, 'through': 2410, 'makes': 2390, 'better': 2382, 'now': 2368, 'work': 2348, 'young': 2344, 'old': 2311, 've': 2307, 'find': 2272, 'both': 2248, 'before': 2179, 'us': 2162, 'again': 2158, 'series': 2153, 'quite': 2144, 'something': 2136, 'cast': 2133, 'should': 2122, 'part': 2098, 'always': 2088, 'lot': 2087, 'another': 2075, 'actors': 2047, 'director': 2040, 'family': 2032, 'between': 2017, 'own': 2016, 'm': 2000, 'may': 1997, 'same': 1973, 'role': 1967, 'watching': 1966, 'every': 1955, 'funny': 1954, 'doesn': 1935, 'performance': 1928, 'few': 1918, 'bad': 1907, 'look': 1901, 're': 1885, 'why': 1855, 'things': 1850, 'times': 1832, 'big': 1816, 'however': 1795, 'actually': 1790, 'action': 1789, 'going': 1784, 'bit': 1757, 'comedy': 1744, 'down': 1741, 'music': 1738, 'must': 1728, 'take': 1710, 'saw': 1693, 'long': 1690, 'right': 1689, 'fun': 1686, 'fact': 1684, 'excellent': 1683, 'around': 1674, 'without': 1673, 'didn': 1672, 'thing': 1662, 'thought': 1639, 'got': 1636, 'each': 1631, 'day': 1615, 'feel': 1597, 'seems': 1596, 'come': 1594, 'done': 1586, 'beautiful': 1580, 'especially': 1572, 'played': 1571, 'almost': 1566, 'want': 1562, 'yet': 1556, 'give': 1554, 'pretty': 1549, 'last': 1543, 'since': 1519, 'different': 1504, 'although': 1501, 'gets': 1491, 'true': 1487, 'interesting': 1481, 'job': 1470, 'enough': 1455, 'our': 1454, 'shows': 1448, 'horror': 1441, 'woman': 1440, 'tv': 1400, 'probably': 1398, 'father': 1395, 'original': 1393, 'girl': 1390, 'point': 1379, 'plays': 1379, 'wonderful': 1372, 'far': 1359, 'course': 1358, 'john': 1350, 'rather': 1340, 'isn': 1330, 'll': 1327, 'later': 1325, 'dvd': 1324, 'war': 1311, 'whole': 1311, 'found': 1307, 'd': 1307, 'away': 1306, 'screen': 1305, 'nothing': 1300, 'once': 1300, 'year': 1297, 'hard': 1294, 'together': 1280, 'am': 1277, 'set': 1277, 'having': 1267, 'making': 1267, 'place': 1263, 'might': 1260, 'comes': 1260, 'sure': 1253, 'american': 1248, 'play': 1245, 'kind': 1244, 'perf ...

# %% [markdown]
# Run the following two cells to list the words used in positive reviews and negative reviews, respectively, ordered from most to least commonly used.

# %%
# Examine the counts of the most common words in positive reviews
positive_counts.most_common()
# Out:
# [('', 550583),
#  ('the', 173367),
#  ('.', 159704),
#  ('and', 89731),
#  ('a', 83715),
#  ('of', 76866),
#  ('to', 66774),
#  ('is', 57256),
#  ('in', 50221),
#  ('br', 49243),
#  ('it', 48036),
#  ('i', 40752),
#  ('that', 35636),
#  ('this', 35082),
#  ('s', 33824),
#  ('as', 26318),
#  ('with', 23251),
#  ('for', 22422),
#  ('was', 21917),
#  ('film', 20938),
#  ('but', 20824),
#  ('movie', 19075),
#  ('his', 17233),
#  ('on', 17020),
#  ('you', 16685),
#  ('he', 16290),
#  ('are', 14810),
#  ('not', 14273),
#  ('t', 13725),
#  ('one', 13658),
#  ('have', 12588),
#  ('be', 12420),
#  ('by', 12000),
#  ('all', 11945),
#  ('who', 11472),
#  ('an', 11296),
#  ('at', 11236),
#  ('from', 10770),
#  ('her', 10476),
#  ('they', 9899),
#  ('has', 9188),
#  ('so', 9154),
#  ('like', 9043),
#  ('about', 8315),
#  ('very', 8305),
#  ('out', 8135),
#  ('there', 8057),
#  ('she', 7779),
#  ('what', 7743),
#  ('or', 7740),
#  ('good', 7721),
#  ('more', 7523),
#  ('when', 7459),
#  ('some', 7442),
#  ('if', 7289),
#  ('just', 7153),
#  ('can', 7005),
#  ('story', 6780),
#  ('time', 6518),
#  ('my', 6490),
#  ('great', 6419),
#  ('well', 6405),
#  ('up', 6322),
#  ('which', 6269),
#  ('their', 6110),
#  ('see', 6030),
#  ('also', 5551),
#  ('we', 5531),
#  ('really', 5476),
#  ('would', 5400),
#  ('will', 5219),
#  ('me', 5169),
#  ('had', 5149),
#  ('only', 5137),
#  ('him', 5018),
#  ('even', 4964),
#  ('most', 4865),
#  ('other', 4861),
#  ('were', 4784),
#  ('first', 4755),
#  ('than', 4738),
#  ('much', 4686),
#  ('its', 4622),
#  ('no', 4574),
#  ('into', 4544),
#  ('people', 4481),
#  ('best', 4320),
#  ('love', 4303),
#  ('get', 4272),
#  ('how', 4213),
#  ('life', 4201),
#  ('been', 4190),
#  ('because', 4079),
#  ('way', 4036),
#  ('do', 3944),
#  ('made', 3823),
#  ('films', 3814),
#  ('them', 3805),
#  ('after', 3802),
#  ('many', 3767),
#  ('two', 3734),
#  ('too', 3660),
#  ('think', 3657),
#  ('movies', 3586),
#  ('characters', 3561),
#  ('character', 3515),
#  ('don', 3469),
#  ('man', 3461),
#  ('show', 3434),
#  ('watch', 3424),
#  ('seen', 3415),
#  ('then', 3358),
#  ('little', 3341),
#  ('still', 3340),
#  ('make', 3304),
#  ('could', 3237),
#  ('never', 3227),
#  ('being', 3222),
#  ('where', 3179),
#  ('does', 3069),
#  ('over', 3018),
#  ('any', 3002),
#  ('while', 2901),
#  ('know', 2834),
#  ('did', 2792),
#  ('years', 2760),
#  ('here', 2742),
#  ('ever', 2735),
#  ('end', 2697),
#  ('these', 2694),
#  ('such', 2593),
#  ('scene', 2570),
#  ('real', 2568),
#  ('back', 2547),
#  ('those', 2486),
#  ('though', 2475),
#  ('off', 2464),
#  ('new', 2458),
#  ('your', 2454),
#  ('go', 2440),
#  ('acting', 2438),
#  ('plot', 2433),
#  ('world', 2430),
#  ('scenes', 2428),
#  ('say', 2414),
#  ('through', 2410),
#  ('makes', 2390),
#  ('better', 2382),
#  ('now', 2368),
#  ('work', 2348),
#  ('young', 2344),
#  ('old', 2311),
#  ('ve', 2307),
#  ('find', 2272),
#  ('both', 2248),
#  ('before', 2179),
#  ('us', 2162),
#  ('again', 2158),
#  ('series', 2153),
#  ('quite', 2144),
#  ('something', 2136),
#  ('cast', 2133),
#  ('should', 2122),
#  ('part', 2098),
#  ('always', 2088),
#  ('lot', 2087),
#  ('another', 2075),
#  ('actors', 2047),
#  ('director', 2040),
#  ('family', 2032),
#  ('between', 2017),
#  ('own', 2016),
#  ('m', 2000),
#  ('may', 1997),
#  ('same', 1973),
#  ('role', 1967),
#  ('watching', 1966),
#  ('every', 1955),
#  ('funny', 1954),
#  ('doesn', 1935),
#  ('performance', 1928),
#  ('few', 1918),
#  ('bad', 1907),
#  ('look', 1901),
#  ('re', 1885),
#  ('why', 1855),
#  ('things', 1850),
#  ('times', 1832),
#  ('big', 1816),
#  ('however', 1795),
#  ('actually', 1790),
#  ('action', 1789),
#  ('going', 1784),
#  ('bit', 1757),
#  ('comedy', 1744),
#  ('down', 1741),
#  ('music', 1738),
#  ('must', 1728),
#  ('take', 1710),
#  ('saw', 1693),
#  ('long', 1690),
#  ('right', 1689),
#  ('fun', 1686),
#  ('fact', 1684),
#  ('excellent', 1683),
#  ('around', 1674),
#  ('without', 1673),
#  ('didn', 1672),
#  ('thing', 1662),
#  ('thought', 1639),
#  ('got', 1636),
#  ('each', 1631),
#  ('day', 1615),
#  ('feel', 1597),
#  ('seems', 1596),
#  ('come', 1594),
#  ('done', 1586),
#  ('beautiful', 1580),
#  ('especially', 1572),
#  ('played', 1571),
#  ('almost', 1566),
#  ('want', 1562),
#  ('yet', 1556),
#  ('give', 1554),
#  ('pretty', 1549),
#  ('last', 1543),
#  ('since', 1519),
#  ('different', 1504),
#  ('although', 1501),
#  ('gets', 1491),
#  ('true', 1487),
#  ('interesting', 1481),
#  ('job', 1470),
#  ('enough', 1455),
#  ('our', 1454),
#  ('shows', 1448),
#  ('horror', 1441),
#  ('woman', 1440),
#  ('tv', 1400),
#  ('probably', 1398),
#  ('father', 1395),
#  ('original', 1393),
#  ('girl', 1390),
#  ('point', 1379),
#  ('plays', 1379),
#  ('wonderful', 1372),
#  ('far', 1359),
#  ('course', 1358),
#  ('john', 1350),
#  ('rather', 1340),
#  ('isn', 1330),
#  ('ll', 1327),
#  ('later', 1325),
#  ('dvd', 1324),
#  ('war', 1311),
#  ('whole', 1311),
#  ('found', 1307),
#  ('d', 1307),
#  ('away', 1306),
#  ('screen', 1305),
#  ('nothing', 1300),
#  ('once', 1300),
#  ('year', 1297),
#  ('hard', 1294),
#  ('together', 1280),
#  ('am', 1277),
#  ('set', 1277),
#  ('having', 1267),
#  ('making', 1267),
#  ('place', 1263),
#  ('might', 1260),
#  ('comes', 1260),
#  ('sure', 1253),
#  ('american', 1248),
#  ('play', 1245),
#  ('kind', 1244),
#  ('perfect', 1242),
#  ('takes', 1242),
#  ('performances', 1237),
#  ('himself', 1230),
#  ('everyone', 1221),
#  ('worth', 1221),
#  ('anyone', 1214),
#  ('actor', 1203),
#  ('three', 1202),
#  ('wife', 1196),
#  ('classic', 1194),
#  ('goes', 1186),
#  ('ending', 1178),
#  ('version', 1168),
#  ('star', 1149),
#  ('enjoy', 1146),
#  ('book', 1142),
#  ('nice', 1132),
#  ('everything', 1131),
#  ('during', 1124),
#  ('put', 1118),
#  ('seeing', 1111),
#  ('least', 1102),
#  ('house', 1100),
#  ('high', 1100),
#  ('watched', 1094),
#  ('loved', 1087),
#  ('men', 1087),
#  ('night', 1082),
#  ('anything', 1076),
#  ('believe', 1072),
#  ('guy', 1071),
#  ('top', 1063),
#  ('amazing', 1058),
#  ('hollywood', 1056),
#  ('looking', 1053),
#  ('main', 1044),
#  ('definitely', 1043),
#  ('home', 1031),
#  ('gives', 1031),
#  ('seem', 1028),
#  ('episode', 1024),
#  ('audience', 1020),
#  ('sense', 1020),
#  ('truly', 1017),
#  ('special', 1011),
#  ('second', 1010),
#  ('short', 1009),
#  ('fan', 1009),
#  ('mind', 1005),
#  ('human', 1002),
#  ('recommend', 999),
#  ('full', 996),
#  ('black', 995),
#  ('help', 993),
#  ('along', 989),
#  ('trying', 987),
#  ('small', 986),
#  ('death', 985),
#  ('friends', 981),
#  ('remember', 974),
#  ('often', 971),
#  ('said', 966),
#  ('favorite', 963),
#  ('heart', 959),
#  ('early', 957),
#  ('left', 956),
#  ('until', 956),
#  ('let', 954),
#  ('script', 954),
#  ('maybe', 939),
#  ('today', 936),
#  ('live', 936),
#  ('less', 934),
#  ('moments', 933),
#  ('others', 930),
#  ('brilliant', 927),
#  ('shot', 925),
#  ('liked', 923),
#  ('become', 916),
#  ('won', 915),
#  ('used', 912),
#  ('style', 907),
#  ('mother', 895),
#  ('lives', 894),
#  ('came', 893),
#  ('stars', 891),
#  ('cinema', 889),
#  ('looks', 885),
#  ('perhaps', 884),
#  ('read', 882),
#  ('enjoyed', 879),
#  ('boy', 875),
#  ('drama', 873),
#  ('given', 872),
#  ('highly', 871),
#  ('playing', 867),
#  ('use', 864),
#  ('next', 861),
#  ('women', 858),
#  ('fine', 857),
#  ('effects', 856),
#  ('kids', 855),
#  ('entertaining', 853),
#  ('need', 852),
#  ('line', 851),
#  ('works', 848),
#  ('someone', 847),
#  ('mr', 836),
#  ('simply', 835),
#  ('picture', 833),
#  ('children', 833),
#  ('face', 832),
#  ('friend', 831),
#  ('keep', 831),
#  ('dark', 830),
#  ('overall', 828),
#  ('certainly', 828),
#  ('minutes', 827),
#  ('wasn', 825),
#  ('history', 822),
#  ('finally', 820),
#  ('couple', 816),
#  ('against', 815),
#  ('son', 809),
#  ('lost', 808),
#  ('understand', 808),
#  ('michael', 805),
#  ('else', 801),
#  ('throughout', 798),
#  ('fans', 797),
#  ('city', 792),
#  ('reason', 789),
#  ('written', 788),
#  ('production', 787),
#  ('school', 786),
#  ('several', 784),
#  ('rest', 781),
#  ('based', 781),
#  ('try', 780),
#  ('dead', 776),
#  ('hope', 775),
#  ('strong', 768),
#  ('white', 765),
#  ('tell', 759),
#  ('itself', 758),
#  ('half', 753),
#  ('person', 749),
#  ('sometimes', 746),
#  ('start', 744),
#  ('past', 744),
#  ('genre', 743),
#  ('beginning', 739),
#  ('final', 739),
#  ('town', 738),
#  ('art', 734),
#  ('humor', 732),
#  ('game', 732),
#  ('yes', 731),
#  ('idea', 731),
#  ('late', 730),
#  ('becomes', 729),
#  ('despite', 729),
#  ('able', 726),
#  ('case', 726),
#  ('money', 725),
#  ('child', 721),
#  ('completely', 721),
#  ('side', 720),
#  ('camera', 716),
#  ('getting', 714),
#  ('instead', 713),
#  ('soon', 702),
#  ('under', 700),
#  ('viewer', 699),
#  ('age', 698),
#  ('days', 697),
#  ('stories', 696),
#  ('felt', 694),
#  ('simple', 694),
#  ('roles', 693),
#  ('video', 688),
#  ('name', 684),
#  ('either', 683),
#  ('doing', 677),
#  ('turns', 674),
#  ('wants', 673),
#  ('close', 671),
#  ('title', 669),
#  ('wrong', 668),
#  ('went', 666),
#  ('james', 665),
#  ('evil', 659),
#  ('budget', 657),
#  ('episodes', 657),
#  ('relationship', 655),
#  ('fantastic', 654),
#  ('piece', 653),
#  ('david', 651),
#  ('turn', 648),
#  ('murder', 646),
#  ('parts', 645),
#  ('brother', 644),
#  ('head', 643),
#  ('absolutely', 643),
#  ('experience', 642),
#  ('eyes', 641),
#  ('sex', 638),
#  ('called', 637),
#  ('direction', 637),
#  ('directed', 636),
#  ('lines', 634),
#  ('behind', 633),
#  ('sort', 632),
#  ('actress', 631),
#  ('lead', 631),
#  ('including', 628),
#  ('oscar', 628),
#  ('example', 627),
#  ('musical', 625),
#  ('known', 625),
#  ('chance', 621),
#  ('score', 620),
#  ('already', 620),
#  ('hit', 619),
#  ('feeling', 619),
#  ('voice', 615),
#  ('moment', 612),
#  ('living', 612),
#  ('supporting', 610),
#  ('low', 610),
#  ('ago', 609),
#  ('themselves', 608),
#  ('reality', 606),
#  ('hilarious', 605),
#  ('jack', 604),
#  ('told', 603),
#  ('hand', 602),
#  ('quality', 600),
#  ('moving', 600),
#  ('matter', 600),
#  ('dialogue', 600),
#  ('happy', 599),
#  ('song', 599),
#  ('paul', 598),
#  ('light', 594),
#  ('future', 594),
#  ('entire', 592),
#  ('finds', 591),
#  ('gave', 589),
#  ('laugh', 587),
#  ('released', 586),
#  ('expect', 585),
#  ('fight', 582),
#  ('particularly', 580),
#  ('cinematography', 579),
#  ('police', 579),
#  ('type', 578),
#  ('whose', 578),
#  ('sound', 578),
#  ('enjoyable', 573),
#  ('view', 573),
#  ('romantic', 572),
#  ('daughter', 572),
#  ('husband', 572),
#  ('number', 572),
#  ('documentary', 571),
#  ('self', 570),
#  ('superb', 570),
#  ('robert', 569),
#  ('took', 569),
#  ('modern', 569),
#  ('mean', 566),
#  ('shown', 563),
#  ('coming', 561),
#  ('important', 560),
#  ('king', 559),
#  ('leave', 559),
#  ('change', 558),
#  ('somewhat', 555),
#  ('wanted', 555),
#  ('tells', 554),
#  ('run', 552),
#  ('country', 552),
#  ('career', 552),
#  ('events', 552),
#  ('heard', 550),
#  ('season', 550),
#  ('greatest', 549),
#  ('girls', 549),
#  ('etc', 547),
#  ('care', 546),
#  ('starts', 545),
#  ('english', 542),
#  ('killer', 541),
#  ('tale', 540),
#  ('guys', 540),
#  ('animation', 540),
#  ('totally', 540),
#  ('usual', 540),
#  ('opinion', 535),
#  ('miss', 535),
#  ('easy', 531),
#  ('violence', 531),
#  ('songs', 530),
#  ('british', 528),
#  ('says', 527),
#  ('realistic', 525),
#  ('writing', 524),
#  ('act', 522),
#  ('writer', 522),
#  ('comic', 521),
#  ('thriller', 519),
#  ('television', 517),
#  ('power', 516),
#  ('ones', 515),
#  ('kid', 514),
#  ('york', 513),
#  ('novel', 513),
#  ('problem', 512),
#  ('alone', 512),
#  ('attention', 509),
#  ('involved', 508),
#  ('kill', 508),
#  ('extremely', 507),
#  ('seemed', 506),
#  ('french', 505),
#  ('hero', 505),
#  ('rock', 504),
#  ('stuff', 501),
#  ('wish', 499),
#  ('begins', 498),
#  ('taken', 497),
#  ('sad', 497),
#  ('ways', 496),
#  ('richard', 495),
#  ('knows', 494),
#  ('atmosphere', 493),
#  ('surprised', 491),
#  ('car', 491),
#  ('similar', 491),
#  ('taking', 491),
#  ('george', 491),
#  ('perfectly', 490),
#  ('team', 489),
#  ('sequence', 489),
#  ('eye', 489),
#  ('across', 489),
#  ('room', 488),
#  ('due', 488),
#  ('among', 488),
#  ('powerful', 488),
#  ('serious', 488),
#  ('b', 487),
#  ('cannot', 487),
#  ('order', 487),
#  ('strange', 487),
#  ('beauty', 486),
#  ('famous', 485),
#  ('herself', 484),
#  ('myself', 484),
#  ('happened', 484),
#  ('tries', 484),
#  ('class', 483),
#  ('four', 482),
#  ('cool', 481),
#  ('theme', 479),
#  ('anyway', 479),
#  ('release', 479),
#  ('opening', 478),
#  ('entertainment', 478),
#  ('exactly', 475),
#  ('unique', 475),
#  ('ends', 475),
#  ('slow', 475),
#  ('level', 474),
#  ('easily', 474),
#  ('o', 474),
#  ('red', 474),
#  ('interest', 472),
#  ('happen', 471),
#  ('crime', 470),
#  ('sets', 468),
#  ('viewing', 468),
#  ('memorable', 467),
#  ('stop', 466),
#  ('group', 466),
#  ('knew', 463),
#  ('sister', 463),
#  ('dance', 463),
#  ('problems', 463),
#  ('working', 463),
#  ('message', 463),
#  ('mystery', 461),
#  ('nature', 461),
#  ('bring', 460),
#  ('brought', 459),
#  ('believable', 459),
#  ('thinking', 459),
#  ('mostly', 458),
#  ('couldn', 457),
#  ('disney', 457),
#  ('society', 456),
#  ('lady', 456),
#  ('within', 455),
#  ('blood', 454),
#  ('upon', 453),
#  ('parents', 453),
#  ('meets', 453),
#  ('viewers', 453),
#  ('usually', 452),
#  ('tom', 452),
#  ('form', 452),
#  ('peter', 452),
#  ('soundtrack', 452),
#  ('local', 450),
#  ('certain', 448),
#  ('follow', 448),
#  ('whether', 447),
#  ('possible', 446),
#  ('killed', 445),
#  ('emotional', 445),
#  ('de', 444),
#  ('above', 444),
#  ('middle', 443),
#  ('god', 443),
#  ('flick', 442),
#  ('happens', 442),
#  ('needs', 442),
#  ('masterpiece', 441),
#  ('major', 440),
#  ('period', 440),
#  ('named', 439),
#  ('haven', 439),
#  ('th', 438),
#  ('particular', 438),
#  ('earth', 437),
#  ('feature', 437),
#  ('stand', 436),
#  ('words', 436),
#  ('typical', 435),
#  ('obviously', 433),
#  ('elements', 433),
#  ('romance', 431),
#  ('jane', 430),
#  ('showing', 427),
#  ('yourself', 427),
#  ('fantasy', 426),
#  ('brings', 426),
#  ('guess', 423),
#  ('america', 423),
#  ('unfortunately', 422),
#  ('huge', 422),
#  ('indeed', 421),
#  ('running', 421),
#  ('talent', 420),
#  ('stage', 419),
#  ('started', 418),
#  ('leads', 417),
#  ('sweet', 417),
#  ('japanese', 417),
#  ('deal', 416),
#  ('poor', 416),
#  ('personal', 413),
#  ('incredible', 413),
#  ('fast', 412),
#  ('deep', 410),
#  ('became', 410),
#  ('hours', 409),
#  ('dream', 408),
#  ('giving', 408),
#  ('nearly', 408),
#  ('clearly', 407),
#  ('turned', 407),
#  ('obvious', 406),
#  ('near', 406),
#  ('cut', 405),
#  ('surprise', 405),
#  ('era', 404),
#  ('body', 404),
#  ('female', 403),
#  ('five', 403),
#  ('hour', 403),
#  ('note', 399),
#  ('truth', 398),
#  ('learn', 398),
#  ('match', 397),
#  ('except', 397),
#  ('tony', 397),
#  ('feels', 397),
#  ('street', 395),
#  ('filmed', 394),
#  ('clear', 394),
#  ('complete', 394),
#  ('keeps', 393),
#  ('lots', 393),
#  ('older', 393),
#  ('eventually', 393),
#  ('buy', 392),
#  ('william', 391),
#  ('stewart', 391),
#  ('meet', 390),
#  ('joe', 390),
#  ('fall', 390),
#  ('rating', 389),
#  ('talking', 389),
#  ('dramatic', 389),
#  ('difficult', 389),
#  ('unlike', 389),
#  ('shots', 389),
#  ('means', 388),
#  ('situation', 387),
#  ('appears', 386),
#  ('present', 386),
#  ('subject', 386),
#  ('wonder', 386),
#  ('comments', 385),
#  ('lee', 383),
#  ('general', 383),
#  ('sequences', 383),
#  ('points', 382),
#  ('earlier', 382),
#  ('check', 379),
#  ('gone', 379),
#  ('recommended', 378),
#  ('suspense', 378),
#  ('ten', 378),
#  ('third', 377),
#  ('business', 377),
#  ('leaves', 375),
#  ('beyond', 375),
#  ('talk', 375),
#  ('portrayal', 374),
#  ('beautifully', 373),
#  ('single', 372),
#  ('bill', 372),
#  ('plenty', 371),
#  ('word', 371),
#  ('falls', 370),
#  ('whom', 370),
#  ('scary', 369),
#  ('non', 369),
#  ('battle', 369),
#  ('using', 369),
#  ('figure', 369),
#  ('return', 368),
#  ('doubt', 367),
#  ('add', 367),
#  ('hear', 366),
#  ('solid', 366),
#  ('success', 366),
#  ('jokes', 365),
#  ('touching', 365),
#  ('political', 365),
#  ('oh', 365),
#  ('hell', 364),
#  ('awesome', 364),
#  ('boys', 364),
#  ('recently', 362),
#  ('dog', 362),
#  ('sexual', 362),
#  ('wouldn', 361),
#  ('please', 361),
#  ('straight', 361),
#  ('features', 361),
#  ('forget', 360),
#  ('setting', 360),
#  ('lack', 360),
#  ('married', 359),
#  ('mark', 359),
#  ('social', 357),
#  ('interested', 356),
#  ('adventure', 356),
#  ('terrific', 355),
#  ('sees', 355),
#  ('actual', 355),
#  ('brothers', 355),
#  ('move', 355),
#  ('call', 354),
#  ('theater', 353),
#  ('dr', 353),
#  ('various', 353),
#  ('animated', 352),
#  ('western', 351),
#  ('space', 350),
#  ('baby', 350),
#  ('leading', 348),
#  ('disappointed', 348),
#  ('portrayed', 346),
#  ('aren', 346),
#  ('screenplay', 345),
#  ('smith', 345),
#  ('hate', 344),
#  ('towards', 344),
#  ('noir', 343),
#  ('kelly', 342),
#  ('outstanding', 342),
#  ('decent', 342),
#  ('directors', 341),
#  ('none', 341),
#  ('journey', 341),
#  ('rich', 341),
#  ('looked', 340),
#  ('effective', 340),
#  ('cold', 339),
#  ('sci', 339),
#  ('mary', 339),
#  ('fi', 339),
#  ('storyline', 339),
#  ('caught', 339),
#  ('charming', 338),
#  ('manages', 337),
#  ('harry', 337),
#  ('popular', 337),
#  ('rare', 337),
#  ('spirit', 336),
#  ('open', 335),
#  ('appreciate', 335),
#  ('basically', 334),
#  ('acted', 334),
#  ('moves', 334),
#  ('pace', 333),
#  ('boring', 333),
#  ('subtle', 333),
#  ('mention', 333),
#  ('inside', 333),
#  ('century', 333),
#  ('deserves', 333),
#  ('familiar', 332),
#  ('background', 332),
#  ('ben', 331),
#  ('creepy', 330),
#  ('supposed', 330),
#  ('secret', 329),
#  ('die', 328),
#  ('jim', 328),
#  ('effect', 327),
#  ('question', 327),
#  ('natural', 327),
#  ('impressive', 326),
#  ('rate', 326),
#  ('language', 326),
#  ('saying', 325),
#  ('intelligent', 325),
#  ('scott', 324),
#  ('realize', 324),
#  ('material', 324),
#  ('telling', 324),
#  ('singing', 323),
#  ('dancing', 322),
#  ('adult', 321),
#  ('visual', 321),
#  ('imagine', 321),
#  ('office', 320),
#  ('kept', 320),
#  ('uses', 319),
#  ('pure', 318),
#  ('wait', 318),
#  ('stunning', 318),
#  ('seriously', 317),
#  ('previous', 317),
#  ('review', 317),
#  ('copy', 317),
#  ('magic', 316),
#  ('reading', 316),
#  ('create', 316),
#  ('hot', 316),
#  ('somehow', 316),
#  ('created', 316),
#  ('air', 315),
#  ('attempt', 315),
#  ('escape', 315),
#  ('crazy', 315),
#  ('stay', 315),
#  ('frank', 315),
#  ('hands', 314),
#  ('filled', 313),
#  ('average', 312),
#  ('surprisingly', 312),
#  ('expected', 312),
#  ('complex', 311),
#  ('quickly', 310),
#  ('successful', 310),
#  ('studio', 310),
#  ('male', 309),
#  ('plus', 309),
#  ('co', 307),
#  ('casting', 306),
#  ('following', 306),
#  ('minute', 306),
#  ('exciting', 306),
#  ('images', 306),
#  ('reasons', 305),
#  ('members', 305),
#  ('german', 305),
#  ('themes', 305),
#  ('follows', 305),
#  ('e', 305),
#  ('free', 304),
#  ('cute', 304),
#  ('touch', 304),
#  ('genius', 304),
#  ('edge', 304),
#  ('outside', 303),
#  ('reviews', 302),
#  ('younger', 302),
#  ('admit', 302),
#  ('fighting', 302),
#  ('ok', 302),
#  ('odd', 301),
#  ('master', 301),
#  ('break', 300),
#  ('thanks', 300),
#  ('comment', 300),
#  ('recent', 300),
#  ('apart', 299),
#  ('emotions', 298),
#  ('lovely', 298),
#  ('begin', 298),
#  ('doctor', 297),
#  ('italian', 297),
#  ('party', 297),
#  ('missed', 296),
#  ('la', 296),
#  ...]

# %%
# Examine the counts of the most common words in negative reviews
negative_counts.most_common()
# Out:
# [('', 561634),
#  ('.', 167569),
#  ('the', 163446),
#  ('a', 79350),
#  ('and', 74386),
#  ('of', 69035),
#  ('to', 68988),
#  ('br', 52645),
#  ('is', 50099),
#  ('it', 48341),
#  ('i', 46892),
#  ('in', 43761),
#  ('this', 40929),
#  ('that', 37620),
#  ('s', 31559),
#  ('was', 26293),
#  ('movie', 24965),
#  ('for', 21933),
#  ('but', 21786),
#  ('with', 20892),
#  ('as', 20636),
#  ('t', 20368),
#  ('film', 19221),
#  ('you', 17550),
#  ('on', 17196),
#  ('not', 16359),
#  ('have', 15148),
#  ('are', 14627),
#  ('be', 14544),
#  ('he', 13857),
#  ('one', 13138),
#  ('they', 13014),
#  ('at', 12279),
#  ('his', 12150),
#  ('all', 12036),
#  ('so', 11466),
#  ('like', 11240),
#  ('there', 10779),
#  ('just', 10624),
#  ('by', 10554),
#  ('or', 10279),
#  ('an', 10270),
#  ('who', 9972),
#  ('from', 9732),
#  ('if', 9522),
#  ('about', 9063),
#  ('out', 8986),
#  ('what', 8422),
#  ('some', 8307),
#  ('no', 8145),
#  ('her', 7948),
#  ('even', 7691),
#  ('can', 7656),
#  ('has', 7608),
#  ('good', 7425),
#  ('bad', 7402),
#  ('would', 7038),
#  ('up', 6972),
#  ('only', 6782),
#  ('more', 6732),
#  ('when', 6728),
#  ('she', 6444),
#  ('really', 6262),
#  ('time', 6214),
#  ('had', 6142),
#  ('my', 6016),
#  ('were', 6003),
#  ('which', 5781),
#  ('very', 5764),
#  ('me', 5606),
#  ('see', 5454),
#  ('don', 5337),
#  ('we', 5328),
#  ('their', 5278),
#  ('do', 5237),
#  ('story', 5209),
#  ('than', 5186),
#  ('been', 5102),
#  ('much', 5082),
#  ('get', 5037),
#  ('because', 4966),
#  ('people', 4806),
#  ('then', 4762),
#  ('make', 4723),
#  ('could', 4689),
#  ('how', 4688),
#  ('any', 4660),
#  ('into', 4569),
#  ('made', 4543),
#  ('other', 4308),
#  ('first', 4306),
#  ('well', 4254),
#  ('too', 4176),
#  ('them', 4166),
#  ('plot', 4156),
#  ('movies', 4080),
#  ('acting', 4057),
#  ('will', 3994),
#  ('way', 3989),
#  ('most', 3920),
#  ('him', 3858),
#  ('after', 3839),
#  ('its', 3655),
#  ('think', 3645),
#  ('also', 3611),
#  ('characters', 3600),
#  ('off', 3571),
#  ('watch', 3550),
#  ('character', 3508),
#  ('did', 3506),
#  ('why', 3463),
#  ('being', 3394),
#  ('better', 3359),
#  ('know', 3334),
#  ('over', 3317),
#  ('seen', 3267),
#  ('ever', 3263),
#  ('never', 3259),
#  ('your', 3233),
#  ('where', 3221),
#  ('two', 3176),
#  ('little', 3100),
#  ('films', 3080),
#  ('here', 3028),
#  ('m', 3000),
#  ('nothing', 2991),
#  ('say', 2984),
#  ('end', 2955),
#  ('something', 2943),
#  ('should', 2922),
#  ('many', 2910),
#  ('does', 2871),
#  ('thing', 2866),
#  ('show', 2862),
#  ('ve', 2829),
#  ('scene', 2817),
#  ('scenes', 2789),
#  ('these', 2724),
#  ('go', 2717),
#  ('didn', 2647),
#  ('great', 2644),
#  ('watching', 2640),
#  ('re', 2620),
#  ('doesn', 2602),
#  ('through', 2561),
#  ('such', 2545),
#  ('man', 2517),
#  ('worst', 2480),
#  ('actually', 2450),
#  ('actors', 2437),
#  ('life', 2429),
#  ('back', 2425),
#  ('while', 2424),
#  ('director', 2405),
#  ('funny', 2336),
#  ('going', 2319),
#  ('still', 2283),
#  ('another', 2256),
#  ('look', 2249),
#  ('now', 2237),
#  ('old', 2216),
#  ('those', 2214),
#  ('real', 2171),
#  ('few', 2159),
#  ('love', 2152),
#  ('horror', 2150),
#  ('before', 2147),
#  ('want', 2141),
#  ('minutes', 2128),
#  ('pretty', 2116),
#  ('best', 2095),
#  ('though', 2092),
#  ('same', 2081),
#  ('script', 2074),
#  ('work', 2027),
#  ('every', 2025),
#  ('seems', 2023),
#  ('least', 2011),
#  ('enough', 1997),
#  ('down', 1988),
#  ('original', 1984),
#  ('guy', 1964),
#  ('got', 1952),
#  ('around', 1943),
#  ('part', 1942),
#  ('lot', 1892),
#  ('anything', 1875),
#  ('find', 1860),
#  ('new', 1856),
#  ('again', 1850),
#  ('isn', 1850),
#  ('point', 1845),
#  ('things', 1840),
#  ('fact', 1839),
#  ('give', 1823),
#  ('makes', 1814),
#  ('take', 1800),
#  ('thought', 1799),
#  ('d', 1770),
#  ('whole', 1769),
#  ('long', 1761),
#  ('years', 1759),
#  ('however', 1740),
#  ('gets', 1715),
#  ('making', 1697),
#  ('cast', 1694),
#  ('big', 1662),
#  ('might', 1659),
#  ('interesting', 1648),
#  ('money', 1638),
#  ('us', 1629),
#  ('right', 1627),
#  ('far', 1621),
#  ('quite', 1596),
#  ('come', 1595),
#  ('without', 1595),
#  ('almost', 1575),
#  ('action', 1567),
#  ('ll', 1567),
#  ('awful', 1557),
#  ('kind', 1539),
#  ('reason', 1534),
#  ('am', 1531),
#  ('looks', 1530),
#  ('must', 1522),
#  ('done', 1510),
#  ('comedy', 1505),
#  ('someone', 1490),
#  ('trying', 1487),
#  ('wasn', 1484),
#  ('poor', 1481),
#  ('boring', 1479),
#  ('instead', 1478),
#  ('saw', 1475),
#  ('away', 1469),
#  ('girl', 1463),
#  ('probably', 1444),
#  ('sure', 1434),
#  ('believe', 1434),
#  ('looking', 1430),
#  ('stupid', 1428),
#  ('anyone', 1418),
#  ('times', 1406),
#  ('maybe', 1405),
#  ('world', 1404),
#  ('rather', 1395),
#  ('terrible', 1391),
#  ('may', 1390),
#  ('last', 1390),
#  ('since', 1389),
#  ('let', 1385),
#  ('tv', 1383),
#  ('hard', 1374),
#  ('between', 1374),
#  ('waste', 1358),
#  ('woman', 1356),
#  ('feel', 1354),
#  ('effects', 1349),
#  ('half', 1341),
#  ('own', 1333),
#  ('young', 1317),
#  ('music', 1316),
#  ('idea', 1313),
#  ('sense', 1306),
#  ('bit', 1299),
#  ('having', 1281),
#  ('book', 1278),
#  ('found', 1267),
#  ('series', 1263),
#  ('put', 1263),
#  ('goes', 1256),
#  ('worse', 1250),
#  ('said', 1231),
#  ('comes', 1224),
#  ('role', 1222),
#  ('main', 1220),
#  ('else', 1199),
#  ('everything', 1197),
#  ('yet', 1196),
#  ('low', 1189),
#  ('screen', 1188),
#  ('supposed', 1186),
#  ('actor', 1185),
#  ('either', 1185),
#  ('ending', 1179),
#  ('budget', 1179),
#  ('audience', 1179),
#  ('set', 1178),
#  ('family', 1170),
#  ('left', 1169),
#  ('completely', 1168),
#  ('both', 1158),
#  ('wrong', 1155),
#  ('always', 1151),
#  ('course', 1149),
#  ('place', 1149),
#  ('seem', 1148),
#  ('watched', 1142),
#  ('day', 1132),
#  ('simply', 1130),
#  ('shot', 1126),
#  ('mean', 1117),
#  ('dead', 1102),
#  ('special', 1102),
#  ('three', 1098),
#  ('house', 1085),
#  ('oh', 1084),
#  ('night', 1083),
#  ('read', 1082),
#  ('less', 1067),
#  ('high', 1066),
#  ('year', 1064),
#  ('camera', 1061),
#  ('worth', 1057),
#  ('our', 1056),
#  ('try', 1051),
#  ('horrible', 1047),
#  ('sex', 1046),
#  ('video', 1044),
#  ('black', 1039),
#  ('although', 1038),
#  ('couldn', 1036),
#  ('once', 1034),
#  ('rest', 1022),
#  ('dvd', 1021),
#  ('line', 1018),
#  ('played', 1017),
#  ('fun', 1007),
#  ('during', 1006),
#  ('production', 1005),
#  ('everyone', 1002),
#  ('play', 993),
#  ('mind', 990),
#  ('version', 990),
#  ('kids', 989),
#  ('seeing', 988),
#  ('american', 980),
#  ('given', 979),
#  ('used', 969),
#  ('performance', 968),
#  ('together', 963),
#  ('especially', 963),
#  ('tell', 959),
#  ('women', 958),
#  ('start', 956),
#  ('need', 955),
#  ('second', 954),
#  ('takes', 952),
#  ('each', 950),
#  ('wife', 944),
#  ('dialogue', 944),
#  ('use', 940),
#  ('problem', 938),
#  ('star', 935),
#  ('unfortunately', 933),
#  ('himself', 929),
#  ('doing', 926),
#  ('death', 922),
#  ('name', 921),
#  ('lines', 919),
#  ('killer', 914),
#  ('getting', 913),
#  ('help', 907),
#  ('couple', 904),
#  ('fan', 902),
#  ('head', 898),
#  ('crap', 895),
#  ('guess', 888),
#  ('piece', 884),
#  ('nice', 881),
#  ('different', 879),
#  ('school', 876),
#  ('later', 875),
#  ('entire', 869),
#  ('shows', 860),
#  ('next', 858),
#  ('short', 858),
#  ('john', 858),
#  ('seemed', 857),
#  ('hollywood', 850),
#  ('home', 849),
#  ('true', 846),
#  ('person', 846),
#  ('absolutely', 842),
#  ('sort', 841),
#  ('care', 839),
#  ('understand', 836),
#  ('plays', 835),
#  ('felt', 834),
#  ('written', 829),
#  ('title', 828),
#  ('until', 822),
#  ('men', 822),
#  ('flick', 818),
#  ('decent', 816),
#  ('face', 814),
#  ('friends', 810),
#  ('stars', 808),
#  ('job', 807),
#  ('case', 807),
#  ('itself', 804),
#  ('yes', 801),
#  ('perhaps', 800),
#  ('went', 797),
#  ('wanted', 797),
#  ('called', 796),
#  ('annoying', 795),
#  ('ridiculous', 790),
#  ('tries', 790),
#  ('laugh', 788),
#  ('evil', 787),
#  ('along', 787),
#  ('hour', 786),
#  ('top', 785),
#  ('full', 783),
#  ('writing', 780),
#  ('came', 780),
#  ('keep', 770),
#  ('totally', 767),
#  ('playing', 766),
#  ('god', 765),
#  ('won', 764),
#  ('guys', 763),
#  ('already', 762),
#  ('gore', 757),
#  ('direction', 749),
#  ('save', 746),
#  ('lost', 745),
#  ('example', 745),
#  ('sound', 742),
#  ('war', 741),
#  ('attempt', 735),
#  ('except', 733),
#  ('car', 733),
#  ('blood', 732),
#  ('moments', 732),
#  ('obviously', 730),
#  ('act', 729),
#  ('remember', 728),
#  ('kill', 727),
#  ('white', 726),
#  ('truly', 726),
#  ('father', 726),
#  ('b', 725),
#  ('thinking', 720),
#  ('finally', 716),
#  ('ok', 716),
#  ('turn', 711),
#  ('quality', 701),
#  ('lack', 699),
#  ('style', 694),
#  ('wouldn', 693),
#  ('cheap', 691),
#  ('none', 690),
#  ('kid', 686),
#  ('please', 686),
#  ('boy', 685),
#  ('seriously', 684),
#  ('lead', 680),
#  ('dull', 679),
#  ('starts', 677),
#  ('children', 676),
#  ('stuff', 673),
#  ('hope', 672),
#  ('looked', 670),
#  ('under', 669),
#  ('recommend', 669),
#  ('run', 668),
#  ('killed', 667),
#  ('others', 666),
#  ('enjoy', 666),
#  ('etc', 663),
#  ('myself', 663),
#  ('against', 662),
#  ('girls', 662),
#  ('beginning', 662),
#  ('small', 660),
#  ('obvious', 660),
#  ('hell', 659),
#  ('slow', 658),
#  ('hand', 656),
#  ('lame', 652),
#  ('wonder', 652),
#  ('picture', 651),
#  ('becomes', 651),
#  ('based', 650),
#  ('early', 648),
#  ('behind', 647),
#  ('poorly', 644),
#  ('avoid', 642),
#  ('happens', 640),
#  ('complete', 640),
#  ('apparently', 640),
#  ('classic', 638),
#  ('anyway', 638),
#  ('several', 636),
#  ('episode', 635),
#  ('certainly', 635),
#  ('despite', 635),
#  ('often', 631),
#  ('cut', 631),
#  ('writer', 630),
#  ('mother', 628),
#  ('predictable', 628),
#  ('gave', 628),
#  ('become', 628),
#  ('close', 625),
#  ('fans', 624),
#  ('saying', 621),
#  ('scary', 619),
#  ('stop', 618),
#  ('live', 618),
#  ('wants', 617),
#  ('self', 615),
#  ('mr', 612),
#  ('friend', 611),
#  ('jokes', 611),
#  ('cannot', 610),
#  ('overall', 609),
#  ('cinema', 604),
#  ('child', 603),
#  ('silly', 602),
#  ('beautiful', 596),
#  ('human', 595),
#  ('liked', 595),
#  ('expect', 594),
#  ('happened', 592),
#  ('bunch', 591),
#  ('entertaining', 591),
#  ('actress', 588),
#  ('final', 588),
#  ('says', 585),
#  ('performances', 584),
#  ('turns', 577),
#  ('humor', 577),
#  ('themselves', 576),
#  ('eyes', 576),
#  ('hours', 574),
#  ('happen', 573),
#  ('basically', 572),
#  ('days', 572),
#  ('running', 572),
#  ('involved', 570),
#  ('directed', 569),
#  ('disappointed', 569),
#  ('call', 569),
#  ('group', 568),
#  ('fight', 567),
#  ('daughter', 567),
#  ('talking', 566),
#  ('body', 566),
#  ('badly', 566),
#  ('sorry', 565),
#  ('throughout', 563),
#  ('viewer', 563),
#  ('extremely', 562),
#  ('yourself', 562),
#  ('heard', 561),
#  ('violence', 561),
#  ('interest', 561),
#  ('shots', 560),
#  ('side', 557),
#  ('word', 556),
#  ('art', 555),
#  ('possible', 554),
#  ('dark', 551),
#  ('game', 551),
#  ('hero', 550),
#  ('alone', 549),
#  ('son', 548),
#  ('type', 547),
#  ('leave', 547),
#  ('gives', 546),
#  ('single', 546),
#  ('parts', 546),
#  ('started', 545),
#  ('female', 543),
#  ('rating', 541),
#  ('voice', 541),
#  ('aren', 541),
#  ('mess', 541),
#  ('town', 540),
#  ('drama', 538),
#  ('definitely', 537),
#  ('unless', 536),
#  ('review', 534),
#  ('effort', 533),
#  ('weak', 533),
#  ('able', 533),
#  ('took', 531),
#  ('non', 530),
#  ('five', 530),
#  ('usually', 529),
#  ('michael', 529),
#  ('matter', 529),
#  ('feeling', 526),
#  ('huge', 524),
#  ('sequel', 523),
#  ('soon', 521),
#  ('exactly', 520),
#  ('turned', 520),
#  ('past', 519),
#  ('police', 518),
#  ('tried', 515),
#  ('middle', 514),
#  ('talent', 513),
#  ('genre', 512),
#  ('zombie', 510),
#  ('history', 509),
#  ('ends', 509),
#  ('opening', 503),
#  ('straight', 503),
#  ('coming', 501),
#  ('serious', 501),
#  ('moment', 500),
#  ('lives', 499),
#  ('sad', 499),
#  ('particularly', 498),
#  ('dialog', 498),
#  ('editing', 493),
#  ('clearly', 492),
#  ('earth', 491),
#  ('beyond', 491),
#  ('level', 490),
#  ('cool', 490),
#  ('taken', 490),
#  ('dumb', 489),
#  ('okay', 488),
#  ('major', 487),
#  ('fast', 486),
#  ('premise', 485),
#  ('stories', 484),
#  ('joke', 484),
#  ('minute', 483),
#  ('wasted', 483),
#  ('mostly', 482),
#  ('rent', 482),
#  ('across', 482),
#  ('fails', 481),
#  ('late', 481),
#  ('falls', 481),
#  ('mention', 478),
#  ('theater', 475),
#  ('sometimes', 472),
#  ('stay', 472),
#  ('hit', 469),
#  ('fine', 467),
#  ('talk', 467),
#  ('die', 466),
#  ('storyline', 465),
#  ('pointless', 465),
#  ('taking', 464),
#  ('order', 462),
#  ('brother', 461),
#  ('whatever', 460),
#  ('told', 460),
#  ('wish', 458),
#  ('room', 456),
#  ('appears', 455),
#  ('write', 455),
#  ('career', 455),
#  ('known', 455),
#  ('husband', 454),
#  ('sit', 451),
#  ('living', 451),
#  ('ten', 450),
#  ('words', 449),
#  ('monster', 448),
#  ('chance', 448),
#  ('add', 444),
#  ('novel', 444),
#  ('hate', 444),
#  ('english', 443),
#  ('somehow', 441),
#  ('strange', 440),
#  ('actual', 438),
#  ('imdb', 438),
#  ('killing', 437),
#  ('total', 437),
#  ('ones', 437),
#  ('material', 437),
#  ('knew', 436),
#  ('king', 434),
#  ('number', 434),
#  ('lee', 433),
#  ('using', 433),
#  ('works', 431),
#  ('shown', 431),
#  ('giving', 431),
#  ('power', 431),
#  ('possibly', 430),
#  ('points', 430),
#  ('kept', 430),
#  ('four', 429),
#  ('including', 427),
#  ('local', 427),
#  ('usual', 426),
#  ('problems', 425),
#  ('opinion', 424),
#  ('ago', 424),
#  ('nudity', 423),
#  ('age', 422),
#  ('due', 421),
#  ('roles', 420),
#  ('decided', 419),
#  ('writers', 419),
#  ('near', 419),
#  ('easily', 418),
#  ('flat', 418),
#  ('experience', 417),
#  ('murder', 417),
#  ('reviews', 416),
#  ('imagine', 415),
#  ('feels', 413),
#  ('somewhat', 411),
#  ('plain', 411),
#  ('class', 410),
#  ('score', 410),
#  ('song', 409),
#  ('whether', 409),
#  ('bring', 409),
#  ('otherwise', 408),
#  ('average', 408),
#  ('whose', 408),
#  ('cinematography', 407),
#  ('knows', 407),
#  ('nearly', 407),
#  ('pathetic', 407),
#  ('zombies', 407),
#  ('cheesy', 406),
#  ('upon', 406),
#  ('city', 405),
#  ('space', 405),
#  ('james', 405),
#  ('credits', 405),
#  ('lots', 404),
#  ('change', 403),
#  ('nor', 402),
#  ('entertainment', 402),
#  ('wait', 401),
#  ('released', 400),
#  ('shame', 400),
#  ('needs', 399),
#  ('attention', 396),
#  ('comments', 394),
#  ('free', 393),
#  ('expected', 393),
#  ('bored', 393),
#  ('lady', 393),
#  ('needed', 392),
#  ('clear', 392),
#  ('view', 391),
#  ('development', 390),
#  ('doubt', 390),
#  ('check', 390),
#  ('mystery', 389),
#  ('figure', 389),
#  ('excellent', 388),
#  ('garbage', 388),
#  ('sequence', 387),
#  ('television', 386),
#  ('sets', 385),
#  ('o', 385),
#  ('laughable', 384),
#  ('potential', 384),
#  ('robert', 383),
#  ('reality', 382),
#  ('country', 382),
#  ('documentary', 382),
#  ('light', 382),
#  ('general', 382),
#  ('ask', 381),
#  ('footage', 381),
#  ('comic', 380),
#  ('fall', 380),
#  ('begin', 380),
#  ('forced', 379),
#  ('stand', 379),
#  ('thriller', 379),
#  ('trash', 379),
#  ('remake', 379),
#  ('songs', 378),
#  ('within', 377),
#  ('gay', 377),
#  ('george', 376),
#  ('hardly', 376),
#  ('above', 375),
#  ('gone', 375),
#  ('means', 374),
#  ('sounds', 373),
#  ('move', 372),
#  ('buy', 372),
#  ('directing', 372),
#  ('david', 372),
#  ('rock', 371),
#  ('forward', 371),
#  ('important', 371),
#  ('british', 370),
#  ('filmed', 370),
#  ('haven', 370),
#  ('hot', 370),
#  ('reading', 369),
#  ('heart', 369),
#  ('fake', 369),
#  ('weird', 368),
#  ('hear', 368),
#  ('incredibly', 368),
#  ('musical', 367),
#  ('hilarious', 367),
#  ('cop', 367),
#  ('enjoyed', 367),
#  ('happy', 366),
#  ('message', 366),
#  ('pay', 366),
#  ('box', 365),
#  ('laughs', 365),
#  ('suspense', 364),
#  ('sadly', 363),
#  ('third', 362),
#  ('eye', 362),
#  ('named', 361),
#  ('similar', 361),
#  ('modern', 360),
#  ('failed', 359),
#  ('events', 359),
#  ('forget', 358),
#  ('question', 358),
#  ('male', 357),
#  ('finds', 357),
#  ('perfect', 356),
#  ('sister', 355),
#  ('spent', 355),
#  ('result', 354),
#  ('feature', 354),
#  ('girlfriend', 353),
#  ('comment', 353),
#  ('sexual', 352),
#  ('neither', 351),
#  ('richard', 351),
#  ('attempts', 351),
#  ('screenplay', 350),
#  ('elements', 350),
#  ('spoilers', 349),
#  ('brain', 348),
#  ('showing', 348),
#  ('filmmakers', 348),
#  ('miss', 347),
#  ('christmas', 347),
#  ('dr', 347),
#  ('cover', 345),
#  ('red', 344),
#  ('sequences', 344),
#  ('ideas', 343),
#  ('excuse', 343),
#  ('crazy', 343),
#  ('typical', 343),
#  ('baby', 342),
#  ('loved', 341),
#  ('meant', 341),
#  ('fire', 340),
#  ('worked', 340),
#  ('unbelievable', 339),
#  ('follow', 339),
#  ('barely', 337),
#  ('theme', 337),
#  ('producers', 336),
#  ('appear', 336),
#  ('twist', 336),
#  ('plus', 336),
#  ('team', 335),
#  ('directors', 335),
#  ('viewers', 333),
#  ('leads', 332),
#  ('slasher', 332),
#  ('tom', 332),
#  ('gun', 331),
#  ('wrote', 331),
#  ('island', 331),
#  ('working', 331),
#  ('villain', 331),
#  ('open', 330),
#  ('strong', 330),
#  ('realize', 330),
#  ('yeah', 329),
#  ('quickly', 329),
#  ('disappointing', 329),
#  ('positive', 329),
#  ('air', 328),
#  ('eventually', 328),
#  ('honestly', 328),
#  ('period', 328),
#  ('weren', 328),
#  ('simple', 328),
#  ('release', 328),
#  ('doctor', 327),
#  ('kills', 327),
#  ('tells', 327),
#  ('nowhere', 326),
#  ('herself', 326),
#  ('acted', 326),
#  ('dog', 326),
#  ('list', 326),
#  ('walk', 325),
#  ('makers', 324),
#  ('apart', 324),
#  ('subject', 323),
#  ('learn', 322),
#  ('fi', 322),
#  ('jack', 319),
#  ('sci', 319),
#  ('bother', 319),
#  ('admit', 319),
#  ('note', 318),
#  ('hands', 318),
#  ('disappointment', 318),
#  ('casting', 317),
#  ('e', 317),
#  ('certain', 317),
#  ('value', 317),
#  ('grade', 316),
#  ('peter', 316),
#  ('suddenly', 315),
#  ('missing', 315),
#  ('break', 313),
#  ('stick', 313),
#  ('previous', 313),
#  ('form', 313),
#  ('soundtrack', 312),
#  ('front', 311),
#  ('surprised', 311),
#  ('expecting', 311),
#  ('relationship', 310),
#  ('parents', 310),
#  ('surprise', 310),
#  ('shoot', 309),
#  ('today', 309),
#  ('concept', 308),
#  ('leaves', 308),
#  ('somewhere', 308),
#  ('creepy', 308),
#  ('vampire', 308),
#  ('painful', 308),
#  ('future', 308),
#  ('ways', 308),
#  ('ended', 308),
#  ('th', 307),
#  ('spend', 307),
#  ('street', 306),
#  ('difficult', 306),
#  ('effect', 306),
#  ('fighting', 306),
#  ('america', 305),
#  ('c', 305),
#  ('accent', 304),
#  ('joe', 302),
#  ('project', 302),
#  ('truth', 302),
#  ('indeed', 301),
#  ('deal', 301),
#  ('f', 301),
#  ('rate', 300),
#  ('biggest', 300),
#  ('japanese', 299),
#  ('paul', 299),
#  ('redeeming', 298),
#  ('begins', 298),
#  ('utterly', 298),
#  ('college', 298),
#  ('fairly', 297),
#  ('disney', 297),
#  ('york', 297),
#  ('crew', 297),
#  ('co', 296),
#  ('create', 296),
#  ('revenge', 296),
#  ('cartoon', 296),
#  ('computer', 295),
#  ('interested', 295),
#  ('stage', 295),
#  ('outside', 295),
#  ('speak', 294),
#  ('considering', 294),
#  ('among', 294),
#  ('towards', 293),
#  ('channel', 293),
#  ('sick', 293),
#  ('talented', 292),
#  ('reasons', 292),
#  ('hair', 292),
#  ('cause', 292),
#  ('bottom', 292),
#  ('particular', 292),
#  ('van', 292),
#  ('cat', 290),
#  ('telling', 290),
#  ('mediocre', 290),
#  ('supporting', 289),
#  ('store', 289),
#  ('background', 288),
#  ('hoping', 288),
#  ...]

# %% [markdown]
# As you can see, common words like "the" appear very often in both positive and negative reviews. Instead of finding the most common words in positive or negative reviews, what you really want are the words found in positive reviews more often than in negative reviews, and vice versa. To accomplish this, you'll need to calculate the **ratios** of word usage between positive and negative reviews.
#
# **TODO:** Check all the words you've seen and calculate the ratio of postive to negative uses and store that ratio in `pos_neg_ratios`.
# >Hint: the positive-to-negative ratio for a given word can be calculated with `positive_counts[word] / float(negative_counts[word]+1)`. Notice the `+1` in the denominator – that ensures we don't divide by zero for words that are only seen in positive reviews.

# %%
# Create Counter object to store positive/negative ratios
pos_neg_ratios = Counter()

# TODO: Calculate the ratios of positive and negative uses of the most common words
#       Consider words to be "common" if they've been used at least 100 times


for term, cnt in list(total_counts.most_common()):
    if cnt >= 100:
        pos_neg_ratios[term] = positive_counts[term]/ float(negative_counts[term] + 1)

# %% [markdown]
# Examine the ratios you've calculated for a few words:

# %%
print("Pos-to-neg ratio for 'the' = {}".format(pos_neg_ratios["the"]))
print("Pos-to-neg ratio for 'amazing' = {}".format(pos_neg_ratios["amazing"]))
print("Pos-to-neg ratio for 'terrible' = {}".format(pos_neg_ratios["terrible"]))
# Out:
# Pos-to-neg ratio for 'the' = 1.0606924568820475
# Pos-to-neg ratio for 'amazing' = 4.022813688212928
# Pos-to-neg ratio for 'terrible' = 0.17744252873563218

# %% [markdown]
# Looking closely at the values you just calculated, we see the following:
#
# * Words that you would expect to see more often in positive reviews – like "amazing" – have a ratio greater than 1. The more skewed a word is toward postive, the farther from 1 its positive-to-negative ratio  will be.
# * Words that you would expect to see more often in negative reviews – like "terrible" – have positive values that are less than 1. The more skewed a word is toward negative, the closer to zero its positive-to-negative ratio will be.
# * Neutral words, which don't really convey any sentiment because you would expect to see them in all sorts of reviews – like "the" – have values very close to 1. A perfectly neutral word – one that was used in exactly the same number of positive reviews as negative reviews – would be almost exactly 1. The `+1` we suggested you add to the denominator slightly biases words toward negative, but it won't matter because it will be a tiny bias and later we'll be ignoring words that are too close to neutral anyway.
#
# Ok, the ratios tell us which words are used more often in postive or negative reviews, but the specific values we've calculated are a bit difficult to work with. A very positive word like "amazing" has a value above 4, whereas a very negative word like "terrible" has a value around 0.18. Those values aren't easy to compare for a couple of reasons:
#
# * Right now, 1 is considered neutral, but the absolute value of the postive-to-negative rations of very postive words is larger than the absolute value of the ratios for the very negative words. So there is no way to directly compare two numbers and see if one word conveys the same magnitude of positive sentiment as another word conveys negative sentiment. So we should center all the values around netural so the absolute value fro neutral of the postive-to-negative ratio for a word would indicate how much sentiment (positive or negative) that word conveys.
# * When comparing absolute values it's easier to do that around zero than one.
#
# To fix these issues, we'll convert all of our ratios to new values using logarithms.
#
# **TODO:** Go through all the ratios you calculated and convert them to logarithms. (i.e. use `np.log(ratio)`)
#
# In the end, extremely positive and extremely negative words will have positive-to-negative ratios with similar magnitudes but opposite signs.

# %%
# TODO: Convert ratios to logs
for term, cnt in  pos_neg_ratios.most_common():
    pos_neg_ratios[term] = np.log(pos_neg_ratios[term])
    
pos_neg_ratios
# Out:
# Counter({'': -0.019874455883785492,
#          'constantly': 0.11042381761437305,
#          'change': 0.32294408442016082,
#          'two': 0.16154268983215178,
#          'theatrical': 0.35139788683788858,
#          'doc': 0.20359895524123955,
#          'linda': -0.11332868530700312,
#          'instance': -0.15201620729862575,
#          'pitt': 1.286210902562908,
#          'homeless': 0.26358452087272044,
#          'classic': 0.62515983957501264,
#          'girlfriend': -0.22032267497256836,
#          'nevertheless': 0.75067102469813185,
#          'wealthy': 0.42172562897994464,
#          'greatest': 1.0248947127715422,
#          'movie': -0.26913632205833854,
#          'darker': 1.3652409519220583,
#          'ian': 0.25704510298989114,
#          'took': 0.067236944784686545,
#          'shark': -1.486835590341768,
#          'intense': 1.0870514662670339,
#          'master': 0.67015766233524654,
#          'ha': -0.8862132766368771,
#          'plays': 0.50048526470860022,
#          'intention': -0.10536051565782628,
#          'wonders': 0.03174869831458027,
#          'code': 0.1930660960769319,
#          'beats': -0.1431008436406733,
#          'rights': 0.36061454194281256,
#          'team': 0.37525132951166773,
#          'son': 0.38770047554896103,
#          'credit': -0.10178269430994236,
#          'annie': -0.63023335514937617,
#          'conversations': -0.09015109699429745,
#          'incoherent': -2.9368917735310576,
#          'drags': -0.78623760362595729,
#          'breaking': 0.45601738727099561,
#          'traveling': 0.49532143723002542,
#          'junk': -1.4945079457601234,
#          'draws': 1.1325138403437911,
#          'then': -0.34953216316337427,
#          'traditional': 0.80535917116687328,
#          'recent': 0.34719619998418855,
#          'heard': -0.021583571667174516,
#          'national': -0.1094842328416884,
#          'vehicle': -0.16068238169047347,
#          'respect': 0.10409389104263336,
#          'bible': -0.8297227155656961,
#          'farce': -0.3784364357202451,
#          'lou': -0.61025952075417766,
#          'site': -0.16296130950941318,
#          'four': 0.11415890536299227,
#          'smart': 0.21209371512762482,
#          'drivel': -2.3470368555648795,
#          'nasty': -0.35950780702303653,
#          'given': -0.11676314775563797,
#          'shoots': -0.38220824594389707,
#          'director': -0.16501580969636206,
#          'means': 0.034079313652862583,
#          'word': -0.40636317731984889,
#          'stupidity': -1.8827312474337816,
#          'blow': -0.10848064299406995,
#          'aunt': 1.023388867430522,
#          'night': -0.0018467225931646629,
#          'expect': -0.01694955831377332,
#          'draw': -0.030153038170687558,
#          'structure': -0.048318577270807683,
#          'beautifully': 1.7626953362841438,
#          'warning': -0.52452446812415254,
#          'shouldn': -0.17693070815907821,
#          'forces': 0.42381424677636087,
#          'originally': 0.31177962403084153,
#          'deliberately': 0.12861737782209354,
#          'hbo': 0.2769867833350329,
#          'bbc': 0.11531084651099439,
#          'opera': -0.0050377940299571808,
#          'turkey': -1.4900911548015341,
#          'whatsoever': -1.5117110216313452,
#          'hired': -0.30932124755526202,
#          'typical': 0.23470437371528577,
#          'unfolds': 1.2163953243244932,
#          'fan': 0.1109924669366235,
#          'witch': 0.068137805167218041,
#          'im': -0.60391604683200273,
#          'genre': 0.37042019954698968,
#          'superbly': 2.2600254785752498,
#          'grant': 0.2898920181025838,
#          'society': 0.72433010799663333,
#          'inept': -1.5824092400461811,
#          'subject': 0.17509385367250144,
#          'using': -0.16224789005987764,
#          'escape': 0.34540086736551434,
#          'slow': -0.32740873046786606,
#          'keeps': 0.44835667273747731,
#          'shadow': 0.36464311358790924,
#          'meaningful': -0.027398974188114388,
#          'elaborate': -0.050430853626891967,
#          'turning': -0.30969820301615603,
#          'hunt': 0.29815337231907629,
#          'liking': 0.091807549253122886,
#          'wasn': -0.58778666490211895,
#          'bob': 0.21808878065258569,
#          'kind': -0.21345042210855003,
#          'anywhere': -0.3646431135879093,
#          'executive': -0.22652764929845035,
#          'robert': 0.39323788153860401,
#          'advantage': 0.42172562897994464,
#          'hong': 1.0438040521731147,
# %% [markdown]
# Examine the new ratios you've calculated for the same words from before:

# %%
print("Pos-to-neg ratio for 'the' = {}".format(pos_neg_ratios["the"]))
print("Pos-to-neg ratio for 'amazing' = {}".format(pos_neg_ratios["amazing"]))
print("Pos-to-neg ratio for 'terrible' = {}".format(pos_neg_ratios["terrible"]))
# Out:
# Pos-to-neg ratio for 'the' = 0.058921956051231586
# Pos-to-neg ratio for 'amazing' = 1.3919815802404802
# Pos-to-neg ratio for 'terrible' = -1.7291085042663878

# %% [markdown]
# If everything worked, now you should see neutral words with values close to zero. In this case, "the" is near zero but slightly positive, so it was probably used in more positive reviews than negative reviews. But look at "amazing"'s ratio - it's above `1`, showing it is clearly a word with positive sentiment. And "terrible" has a similar score, but in the opposite direction, so it's below `-1`. It's now clear that both of these words are associated with specific, opposing sentiments.
#
# Now run the following cells to see more ratios.
#
# The first cell displays all the words, ordered by how associated they are with postive reviews. (Your notebook will most likely truncate the output so you won't actually see *all* the words in the list.)
#
# The second cell displays the 30 words most associated with negative reviews by reversing the order of the first list and then looking at the first 30 words. (If you want the second cell to display all the words, ordered by how associated they are with negative reviews, you could just write `reversed(pos_neg_ratios.most_common())`.)
#
# You should continue to see values similar to the earlier ones we checked – neutral words will be close to `0`, words will get more positive as their ratios approach and go above `1`, and words will get more negative as their ratios approach and go below `-1`. That's why we decided to use the logs instead of the raw ratios.

# %%
# words most frequently seen in a review with a "POSITIVE" label
pos_neg_ratios.most_common()
# Out:
# [('edie', 4.6913478822291435),
#  ('paulie', 4.0775374439057197),
#  ('felix', 3.1527360223636558),
#  ('polanski', 2.8233610476132043),
#  ('matthau', 2.8067217286092401),
#  ('victoria', 2.6810215287142909),
#  ('mildred', 2.6026896854443837),
#  ('gandhi', 2.5389738710582761),
#  ('flawless', 2.451005098112319),
#  ('superbly', 2.2600254785752498),
#  ('perfection', 2.1594842493533721),
#  ('astaire', 2.1400661634962708),
#  ('captures', 2.0386195471595809),
#  ('voight', 2.0301704926730531),
#  ('wonderfully', 2.0218960560332353),
#  ('powell', 1.9783454248084671),
#  ('brosnan', 1.9547990964725592),
#  ('lily', 1.9203768470501485),
#  ('bakshi', 1.9029851043382795),
#  ('lincoln', 1.9014583864844796),
#  ('refreshing', 1.8551812956655511),
#  ('breathtaking', 1.8481124057791867),
#  ('bourne', 1.8478489358790986),
#  ('delightful', 1.8002701588959635),
#  ('flynn', 1.7996646487351682),
#  ('lemmon', 1.7812881693607596),
#  ('andrews', 1.7764919970972666),
#  ('homer', 1.7692866133759964),
#  ('beautifully', 1.7626953362841438),
#  ('soccer', 1.7578579175523736),
#  ('lumet', 1.7462970951512977),
#  ('elvira', 1.7397031072720019),
#  ('underrated', 1.7197859696029656),
#  ('gripping', 1.7165360479904674),
#  ('superb', 1.7109073725989601),
#  ('delight', 1.6714733033535532),
#  ('welles', 1.6677068205580761),
#  ('sadness', 1.663505133704376),
#  ('sinatra', 1.6389967146756448),
#  ('touching', 1.637217476541176),
#  ('timeless', 1.62924053973028),
#  ('macy', 1.6211339521972916),
#  ('unforgettable', 1.6177367152487956),
#  ('favorites', 1.6158688027643908),
#  ('sullivan', 1.6094379124341003),
#  ('hartley', 1.6094379124341003),
#  ('extraordinary', 1.6094379124341003),
#  ('brilliantly', 1.5950491749820008),
#  ('stewart', 1.5866809253114842),
#  ('friendship', 1.5677652160335325),
#  ('wonderful', 1.5645425925262093),
#  ('palma', 1.5553706911638245),
#  ('magnificent', 1.54663701119507),
#  ('finest', 1.5462590108125689),
#  ('jackie', 1.5439233053234738),
#  ('ritter', 1.5404450409471491),
#  ('tremendous', 1.5184661342283736),
#  ('freedom', 1.5091151908062312),
#  ('fantastic', 1.5063736090366242),
#  ('sidney', 1.493925025312256),
#  ('noir', 1.493925025312256),
#  ('outstanding', 1.4910053152089213),
#  ('terrific', 1.4900911548015341),
#  ('mann', 1.4894785973551214),
#  ('pleasantly', 1.4894785973551214),
#  ('nancy', 1.488077055429833),
#  ('marie', 1.4825711915553104),
#  ('marvelous', 1.4739999415389962),
#  ('excellent', 1.4647538505723599),
#  ('ruth', 1.4596256342054401),
#  ('stanwyck', 1.4412101187160054),
#  ('widmark', 1.4350845252893227),
#  ('splendid', 1.4271163556401458),
#  ('tender', 1.423108334242607),
#  ('chan', 1.423108334242607),
#  ('exceptional', 1.4201959127955721),
#  ('gentle', 1.4078005663408544),
#  ('poignant', 1.4022947024663317),
#  ('gem', 1.3932148039644643),
#  ('amazing', 1.3919815802404802),
#  ('fisher', 1.3862943611198906),
#  ('davies', 1.3862943611198906),
#  ('chilling', 1.3862943611198906),
#  ('captivating', 1.3862943611198906),
#  ('darker', 1.3652409519220583),
#  ('april', 1.3499267169490159),
#  ('kelly', 1.3461743673304654),
#  ('blake', 1.3418425985490567),
#  ('overlooked', 1.329135947279942),
#  ('ralph', 1.32818673031261),
#  ('bette', 1.3156767939059373),
#  ('hoffman', 1.3150668518315229),
#  ('cole', 1.3121863889661687),
#  ('shines', 1.3049487216659381),
#  ('powerful', 1.2999662776313934),
#  ('notch', 1.2950456896547455),
#  ('remarkable', 1.2883688239495823),
#  ('pitt', 1.286210902562908),
#  ('winters', 1.2833463918674481),
#  ('vivid', 1.2762934659055623),
#  ('gritty', 1.2757524867200667),
#  ('giallo', 1.2745029551317739),
#  ('portrait', 1.2704625455947689),
#  ('innocence', 1.2694300209805796),
#  ('psychiatrist', 1.2685113254635072),
#  ('favorite', 1.2679345909184248),
#  ('ensemble', 1.2656663733312759),
#  ('stunning', 1.2622417124499117),
#  ('burns', 1.259880436264232),
#  ('garbo', 1.258954938743289),
#  ('barbara', 1.2580400255962119),
#  ('panic', 1.2527629684953681),
#  ('holly', 1.2527629684953681),
#  ('carol', 1.2481440226390734),
#  ('perfect', 1.246742480713785),
#  ('appreciated', 1.2462482874741743),
#  ('journey', 1.2367626271489269),
#  ('rural', 1.235471471385307),
#  ('bond', 1.2321436812926323),
#  ('builds', 1.2305398317106577),
#  ('brilliant', 1.2298347446861542),
#  ('brooklyn', 1.2286654169163074),
#  ('favourite', 1.2276893309432522),
#  ('philip', 1.2253639943072534),
#  ('von', 1.225175011976539),
#  ('unfolds', 1.2163953243244932),
#  ('recommended', 1.2163953243244932),
#  ('daniel', 1.20215296760895),
#  ('perfectly', 1.1971931173405572),
#  ('crafted', 1.1962507582320256),
#  ('prince', 1.1939224684724346),
#  ('troubled', 1.192138346678933),
#  ('consequences', 1.1865810616140668),
#  ('haunting', 1.1814999484738773),
#  ('cinderella', 1.180052620608284),
#  ('alexander', 1.1759989522835299),
#  ('emotions', 1.1753049094563641),
#  ('boxing', 1.1735135968412274),
#  ('subtle', 1.1734135017508081),
#  ('solo', 1.1657515915057384),
#  ('curtis', 1.1649873576129823),
#  ('rare', 1.1566438362402944),
#  ('loved', 1.1563661500586044),
#  ('daughters', 1.1526795099383853),
#  ('courage', 1.1438688802562305),
#  ('dentist', 1.1426722784621401),
#  ('highly', 1.1420208631618658),
#  ('nominated', 1.1409146683587992),
#  ('tony', 1.1397491942285991),
#  ('draws', 1.1325138403437911),
#  ('everyday', 1.1306150197542835),
#  ('contrast', 1.1284652518177909),
#  ('cried', 1.1213405397456659),
#  ('fabulous', 1.1210851445201684),
#  ('fay', 1.120591195386885),
#  ('ned', 1.120591195386885),
#  ('emma', 1.1184149159642893),
#  ('sensitive', 1.113318436057805),
#  ('corruption', 1.1118575154181303),
#  ('smooth', 1.1089750757036563),
#  ('dramas', 1.1080910326226534),
#  ('today', 1.1050431789984001),
#  ('helps', 1.1023091505494358),
#  ('inspiring', 1.0986122886681098),
#  ('jimmy', 1.0937696641923216),
#  ('awesome', 1.0931328229034842),
#  ('rival', 1.0904489780289488),
#  ('unique', 1.0881409888008142),
#  ('tragic', 1.0871835928444868),
#  ('intense', 1.0870514662670339),
#  ('stellar', 1.0857088838322018),
#  ('provides', 1.0797081340289569),
#  ('depression', 1.0782034170369026),
#  ('shy', 1.0775588794702773),
#  ('carrie', 1.076139432816051),
#  ('blend', 1.0753554265038423),
#  ('hank', 1.0736109864626924),
#  ('diana', 1.0726368022648489),
#  ('adorable', 1.0726368022648489),
#  ('unexpected', 1.0722255334949147),
#  ('achievement', 1.0668635903535293),
#  ('bettie', 1.0663514264498881),
#  ('happiness', 1.0632729222228008),
#  ('glorious', 1.0608719606852626),
#  ('davis', 1.0541605260972757),
#  ('terrifying', 1.0525211814678428),
#  ('beauty', 1.050410186850232),
#  ('ideal', 1.0479685558493548),
#  ('fears', 1.0467872208035236),
#  ('hong', 1.0438040521731147),
#  ('seasons', 1.0433496099930604),
#  ('fascinating', 1.0414538748281612),
#  ('carries', 1.0345904299031787),
#  ('satisfying', 1.0321225473992768),
#  ('definite', 1.0319209141694374),
#  ('touched', 1.0296194171811581),
#  ('greatest', 1.0248947127715422),
#  ('creates', 1.0241097613701886),
#  ('aunt', 1.023388867430522),
#  ('walter', 1.022328983918479),
#  ('ann', 1.0221705931681675),
#  ('portrayal', 1.0189810189761024),
#  ('enterprise', 1.0116009116784799),
#  ('musicals', 1.0096648026516135),
#  ('deeply', 1.0094845087721023),
#  ('incredible', 1.0061677561461084),
#  ('mature', 1.0060195018402847),
#  ('spectacular', 1.004793533450455),
#  ('triumph', 0.99682959435816731),
#  ('margaret', 0.99682959435816731),
#  ('harry', 0.99176919305006062),
#  ('lucas', 0.990398704027877),
#  ('sweet', 0.98966110487955483),
#  ('joey', 0.98794672078059009),
#  ('balance', 0.98649499054740353),
#  ('warm', 0.98485340331145166),
#  ('ages', 0.98449898190068863),
#  ('guilt', 0.98082925301172619),
#  ('carrey', 0.98082925301172619),
#  ('glover', 0.98082925301172619),
#  ('learns', 0.97881108885548895),
#  ('unusual', 0.97788374278196932),
#  ('sons', 0.97777581552483595),
#  ('complex', 0.97761897738147796),
#  ('essence', 0.97753435711487369),
#  ('brazil', 0.9769153536905899),
#  ('widow', 0.97650959186720987),
#  ('solid', 0.97537964824416146),
#  ('oscar', 0.97448002533306755),
#  ('beautiful', 0.97326301262841053),
#  ('holmes', 0.97246100334120955),
#  ('navy', 0.97246100334120955),
#  ('awe', 0.97186058302896583),
#  ('eerie', 0.97116734209998934),
#  ('vhs', 0.97116734209998934),
#  ('grim', 0.96873720724669754),
#  ('lonely', 0.96873720724669754),
#  ('sport', 0.96825047080486615),
#  ('debut', 0.96508089604358704),
#  ('destiny', 0.96343751029985703),
#  ('thrillers', 0.96281074750904794),
#  ('tears', 0.95977584381389391),
#  ('rose', 0.95664202739772253),
#  ('ginger', 0.95551144502743635),
#  ('winning', 0.95471810900804055),
#  ('stanley', 0.95387344302319799),
#  ('cox', 0.95343027882361187),
#  ('paris', 0.95278479030472663),
#  ('heart', 0.95238806924516806),
#  ('hooked', 0.95155887071161305),
#  ('comfortable', 0.94803943018873538),
#  ('feelings', 0.94646160950751845),
#  ('mgm', 0.94446160884085151),
#  ('masterpiece', 0.94155039863339296),
#  ('themes', 0.94118828349588235),
#  ('danny', 0.93967118051821874),
#  ('anime', 0.93378388932167222),
#  ('perry', 0.93328830824272613),
#  ('joy', 0.93301752567946861),
#  ('lovable', 0.93081883243706487),
#  ('hal', 0.92953595862417571),
#  ('mysteries', 0.92953595862417571),
#  ('louis', 0.92871325187271225),
#  ('charming', 0.92520609553210742),
#  ('urban', 0.92367083917177761),
#  ('allows', 0.92183091224977043),
#  ('impact', 0.91815814604895041),
#  ('italy', 0.91629073187415511),
#  ('gradually', 0.91629073187415511),
#  ('lifestyle', 0.91629073187415511),
#  ('spy', 0.91289514287301687),
#  ('treat', 0.91193342650519937),
#  ('subsequent', 0.91056005716517008),
#  ('loving', 0.90967549275543591),
#  ('surprising', 0.90937028902958128),
#  ('quiet', 0.90648673177753425),
#  ('winter', 0.90624039602065365),
#  ('reveals', 0.90490540964902977),
#  ('raw', 0.90445627422715225),
#  ('funniest', 0.90078654533818991),
#  ('pleased', 0.89994159387262562),
#  ('norman', 0.89994159387262562),
#  ('thief', 0.89874642222324552),
#  ('season', 0.89827222637147675),
#  ('secrets', 0.89794159320595857),
#  ('colorful', 0.89705936994626756),
#  ('highest', 0.8967461358011849),
#  ('compelling', 0.89462923509297576),
#  ('danes', 0.89248008318043659),
#  ('castle', 0.88967708335606499),
#  ('kudos', 0.88889175768604067),
#  ('bleak', 0.88730319500090271),
#  ('baseball', 0.88730319500090271),
#  ('subtitles', 0.88730319500090271),
#  ('great', 0.88659127701937845),
#  ('tragedy', 0.88563699078315261),
#  ('todd', 0.88551907320740142),
#  ('nicely', 0.87924946019380601),
#  ('arthur', 0.87546873735389985),
#  ('essential', 0.87373111745535925),
#  ('gorgeous', 0.8731725250935497),
#  ('fonda', 0.87294029100054127),
#  ('eastwood', 0.87139541196626402),
#  ('focuses', 0.87082835779739776),
#  ('enjoyed', 0.87070195951624607),
#  ('natural', 0.86997924506912838),
#  ('intensity', 0.86835126958503595),
#  ('witty', 0.86824103423244681),
#  ('rob', 0.8642954367557748),
#  ('worlds', 0.86377269759070874),
#  ('health', 0.86113891179907498),
#  ('magical', 0.85953791528170564),
#  ('deeper', 0.85802182375017932),
#  ('lucy', 0.85618680780444956),
#  ('moving', 0.85566611005772031),
#  ('lovely', 0.85290640004681306),
#  ('purple', 0.8513711857748395),
#  ('memorable', 0.84801189112086062),
#  ('kennedy', 0.84729786038720367),
#  ('sings', 0.84729786038720367),
#  ('craig', 0.84342938360928321),
#  ('modesty', 0.84342938360928321),
#  ('winner', 0.84326559685926517),
#  ('relate', 0.84326559685926517),
#  ('episodes', 0.84223712084137292),
#  ('strong', 0.84167135777060931),
#  ('smith', 0.83959811108590054),
#  ('tear', 0.83704136022001441),
#  ('apartment', 0.83333115290549531),
#  ('disagree', 0.83290912293510388),
#  ('princess', 0.83290912293510388),
#  ('kung', 0.83173334384609199),
#  ('jake', 0.82667857318446791),
#  ('columbo', 0.82667857318446791),
#  ('dancer', 0.82531895366842833),
#  ('adventure', 0.82507472360249334),
#  ('adds', 0.82485652591452319),
#  ('hart', 0.82472353834866463),
#  ('strength', 0.82417544296634937),
#  ('realizes', 0.82360006895738058),
#  ('dave', 0.8232003088081431),
#  ('childhood', 0.82208086393583857),
#  ('forbidden', 0.81989888619908913),
#  ('tight', 0.81883539572344199),
#  ('surreal', 0.8178506590609026),
#  ('manager', 0.81770990320170756),
#  ('con', 0.81093021621632877),
#  ('studios', 0.81093021621632877),
#  ('miike', 0.80821651034473263),
#  ('realistic', 0.80807714723392232),
#  ('explicit', 0.80792269515237358),
#  ('kurt', 0.8060875917405409),
#  ('deals', 0.80535917116687328),
#  ('traditional', 0.80535917116687328),
#  ('holds', 0.80493858654806194),
#  ('carl', 0.80437281567016972),
#  ('touches', 0.80396154690023547),
#  ('gene', 0.80314807577427383),
#  ('albert', 0.8027669055771679),
#  ('abc', 0.80234647252493729),
#  ('cry', 0.80011930011211307),
#  ('sides', 0.7995275841185171),
#  ('eyre', 0.79850769621777162),
#  ('develops', 0.79850769621777162),
#  ('dances', 0.79694397424158891),
#  ('oscars', 0.79633141679517616),
#  ('legendary', 0.79600456599965308),
#  ('importance', 0.79492987486988764),
#  ('hearted', 0.79492987486988764),
#  ('portraying', 0.79356592830699269),
#  ('impressed', 0.79258107754813223),
#  ('waters', 0.79112758892014912),
#  ('empire', 0.79078565012386137),
#  ('edge', 0.789774016249017),
#  ('environment', 0.78845736036427028),
#  ('jean', 0.78845736036427028),
#  ('sentimental', 0.7864791203521645),
#  ('captured', 0.78623760362595729),
#  ('styles', 0.78592891401091158),
#  ('daring', 0.78592891401091158),
#  ('backgrounds', 0.78275933924963248),
#  ('matches', 0.78275933924963248),
#  ('frank', 0.78275933924963248),
#  ('tense', 0.78275933924963248),
#  ('gothic', 0.78209466657644144),
#  ('sharp', 0.7814397877056235),
#  ('achieved', 0.78015855754957497),
#  ('court', 0.77947526404844247),
#  ('steals', 0.7789140023173704),
#  ('rules', 0.77844476107184035),
#  ('colors', 0.77684619943659217),
#  ('reunion', 0.77318988823348167),
#  ('covers', 0.77139937745969345),
#  ('tale', 0.77010822169607374),
#  ('rain', 0.7683706017975328),
#  ('forms', 0.7683706017975328),
#  ('denzel', 0.76804848873306297),
#  ('blob', 0.76725515271366718),
#  ('maria', 0.76214005204689672),
#  ('conventional', 0.76214005204689672),
#  ('fresh', 0.76158434211317383),
#  ('midnight', 0.76096977689870637),
#  ('landscape', 0.75852993982279704),
#  ('animated', 0.75768570169751648),
#  ('titanic', 0.75666058628227129),
#  ('sunday', 0.75666058628227129),
#  ('spring', 0.7537718023763802),
#  ('cagney', 0.7537718023763802),
#  ('enjoyable', 0.75246375771636476),
#  ('immensely', 0.75198768058287868),
#  ('nevertheless', 0.75067102469813185),
#  ('driven', 0.74994477895307854),
#  ('performances', 0.74883252516063137),
#  ('streets', 0.74840985923499481),
#  ('nowadays', 0.74721440183022114),
#  ('memories', 0.74721440183022114),
#  ('simple', 0.74641420974143258),
#  ('golden', 0.74533293373051557),
#  ('leslie', 0.74533293373051557),
#  ('lovers', 0.74497224842453125),
#  ('relationship', 0.74484232345601786),
#  ('supporting', 0.74357803418683721),
#  ('che', 0.74262723782331497),
#  ('packed', 0.7410032017375805),
#  ('trek', 0.74021469141793106),
#  ('provoking', 0.73840377214806618),
#  ('strikes', 0.73759894313077912),
#  ('depiction', 0.73682224406260699),
#  ('emotional', 0.73678211645681524),
#  ('secretary', 0.7366322924996842),
#  ('influenced', 0.73511137965897755),
#  ('florida', 0.73511137965897755),
#  ('sir', 0.73396917508020054),
#  ('stays', 0.73396917508020054),
#  ('germany', 0.73288750920945944),
#  ('brings', 0.73142936713096229),
#  ('lewis', 0.73129894652432159),
#  ('elderly', 0.73088750854279239),
#  ('owner', 0.72743625403857748),
#  ('henry', 0.72642196944481741),
#  ('portrays', 0.72593700338293632),
#  ('bears', 0.7252354951114458),
#  ('china', 0.72489587887452556),
#  ('anger', 0.72439972406404984),
#  ('society', 0.72433010799663333),
#  ('available', 0.72415741730250549),
#  ('best', 0.72322463579722329),
#  ('blues', 0.7230001437096264),
#  ('bugs', 0.72270598280148979),
#  ('magic', 0.71878961117328299),
#  ('delivers', 0.71846498854423513),
#  ('verhoeven', 0.71846498854423513),
#  ('jim', 0.71783979315031676),
#  ('donald', 0.71667767797013937),
#  ('endearing', 0.71465338578090898),
#  ('relationships', 0.71393795022901896),
#  ('greatly', 0.71256526641704687),
#  ('brad', 0.71024161391924534),
#  ('charlie', 0.71024161391924534),
#  ('simon', 0.70967648251115578),
#  ('effectively', 0.70914752190638641),
#  ('march', 0.70774597998109789),
#  ('atmosphere', 0.70744773070214162),
#  ('influence', 0.70733181555190172),
#  ('genius', 0.706392407309966),
#  ('emotionally', 0.70556970055850243),
#  ('ken', 0.70526854109229009),
#  ('identity', 0.70484322032313651),
#  ('sophisticated', 0.70470800296102132),
#  ('dan', 0.70457587638356811),
#  ('andrew', 0.70329955202396321),
#  ('brooks', 0.70188086052869991),
#  ('india', 0.70144598337464037),
#  ('roy', 0.69970458110610434),
#  ('surprisingly', 0.6995780708902356),
#  ('sky', 0.69780919366575667),
#  ('romantic', 0.69664981111114743),
#  ('match', 0.69566924999265523),
#  ('meets', 0.69535712621074819),
#  ('patient', 0.69314718055994529),
#  ('bitter', 0.69314718055994529),
#  ('wave', 0.69314718055994529),
#  ('affected', 0.69314718055994529),
#  ('stylish', 0.69314718055994529),
#  ('britain', 0.69314718055994529),
#  ('beatty', 0.69314718055994529),
#  ('directs', 0.69314718055994529),
#  ('cowboy', 0.69314718055994529),
#  ('love', 0.69245023547423656),
#  ('paul', 0.68980827929443067),
#  ('andy', 0.68846333124751902),
#  ('performance', 0.68797386327972465),
#  ('patrick', 0.68645819240914863),
#  ('unlike', 0.68546468438792907),
#  ('refuses', 0.68348526964820844),
#  ('complaint', 0.6824518914431974),
#  ('ride', 0.68229716453587952),
#  ('dawson', 0.68171848473632257),
#  ('luke', 0.68158635815886937),
#  ('wells', 0.68087708796813096),
#  ('france', 0.6804081547825156),
#  ('handsome', 0.68007509899259255),
#  ('sports', 0.68007509899259255),
#  ('rebel', 0.67875844310784572),
#  ('greater', 0.67605274720064523),
#  ('dreams', 0.67599410133369586),
#  ('effective', 0.67565402311242806),
#  ('succeeds', 0.67544760346054433),
#  ('award', 0.67538472422010487),
#  ('interpretation', 0.67479804189174875),
#  ('brando', 0.67445504754779284),
#  ('works', 0.67445504754779284),
#  ('noble', 0.6737290947028437),
#  ('paced', 0.67314651385327573),
#  ('le', 0.67067432470788668),
#  ('master', 0.67015766233524654),
#  ('h', 0.6696166831497512),
#  ('rings', 0.66904962898088483),
#  ('city', 0.66820823221269321),
#  ('sunshine', 0.66782937257565544),
#  ('easy', 0.66529022605697907),
#  ('relations', 0.664159643686693),
#  ('england', 0.66387679825983203),
#  ('glimpse', 0.66329421741026418),
#  ('aired', 0.66268797307523675),
#  ('sees', 0.66263163663399482),
#  ('both', 0.66248336767382998),
#  ('definitely', 0.66199789483898808),
#  ('imaginative', 0.66139848224536502),
#  ('appreciate', 0.66083893732728749),
#  ('tricks', 0.66071190480679143),
#  ('striking', 0.66071190480679143),
#  ('carefully', 0.65999497324304479),
#  ('complicated', 0.65981076029235353),
#  ('perspective', 0.65962448852130173),
#  ('trilogy', 0.65877953705573755),
#  ('lion', 0.65742909795786608),
#  ('douglas', 0.65540685257709819),
#  ('victor', 0.65540685257709819),
#  ('inspired', 0.65459851044271034),
#  ('marriage', 0.65392646740666405),
#  ('demands', 0.65392646740666405),
#  ('future', 0.65353804246489944),
#  ('divorce', 0.651761964397091),
#  ('father', 0.65172321672194655),
#  ('page', 0.65123628494430852),
#  ('instant', 0.65058756614114943),
#  ('ruthless', 0.64934455790155243),
#  ('saga', 0.64934455790155243),
#  ('joan', 0.64891392558311978),
#  ('joseph', 0.64841128671855386),
#  ('workers', 0.64829661439459352),
#  ('fantasy', 0.64726757480925168),
#  ('accomplished', 0.64551913157069074),
#  ('distant', 0.64551913157069074),
#  ('era', 0.6448286032891376),
#  ('manhattan', 0.64435701639051324),
#  ('personal', 0.64355023942057321),
#  ('meeting', 0.64313675998528386),
#  ('individual', 0.64313675998528386),
#  ('pushing', 0.64313675998528386),
#  ('pleasant', 0.64250344774119039),
#  ('brave', 0.64185388617239469),
#  ('william', 0.64083139119578469),
#  ('hudson', 0.64077919504262937),
#  ('friendly', 0.63949446706762514),
#  ('eccentric', 0.63907995928966954),
#  ('awards', 0.63875310849414646),
#  ('seeking', 0.63808740337691783),
#  ('colonel', 0.63757732940513456),
#  ('jack', 0.63525320214104264),
#  ('jane', 0.63443957973316734),
#  ('shaw', 0.63430668053701189),
#  ('keeping', 0.63414883979798953),
#  ('gives', 0.63383568159497883),
#  ('ted', 0.63342794585832296),
#  ('animation', 0.63208692379869902),
#  ('progress', 0.6317782341836532),
#  ('concert', 0.63127177684185776),
#  ('larger', 0.63127177684185776),
#  ('nation', 0.6296337748376194),
#  ('albeit', 0.62739580299716491),
#  ('adapted', 0.62613647027698516),
#  ('discovers', 0.62542900650499444),
#  ('classic', 0.62515983957501264),
#  ('segment', 0.62335141862440335),
#  ('morgan', 0.62303761437291871),
#  ('mouse', 0.62294292188669675),
#  ('impressive', 0.62211140744319349),
#  ('ultimate', 0.62168821657780038),
#  ('artist', 0.62168821657780038),
#  ('griffith', 0.62117368093485603),
#  ('emily', 0.62082651898031915),
#  ('drew', 0.62082651898031915),
#  ('moved', 0.6197197120051281),
#  ('families', 0.61903920840622351),
#  ('profound', 0.61903920840622351),
#  ('innocent', 0.61851219917136446),
#  ('eddie', 0.61691981517206107),
#  ('criticism', 0.61651395453902935),
#  ('nature', 0.61594514653194088),
#  ('recognized', 0.61518563909023349),
#  ('sexuality', 0.61467556511845012),
#  ('contract', 0.61400986000122149),
#  ('brian', 0.61344043794920278),
#  ('remembered', 0.6131044728864089),
#  ('determined', 0.6123858239154869),
#  ('offers', 0.61207935747116349),
#  ('pleasure', 0.61195702582993206),
#  ('washington', 0.61180154110599294),
#  ('images', 0.61159731359583758),
#  ('games', 0.61067095873570676),
#  ('academy', 0.60872983874736208),
#  ('fashioned', 0.60798937221963845),
#  ('melodrama', 0.60749173598145145),
#  ('rough', 0.60613580357031549),
#  ('versions', 0.60613580357031549),
#  ('charismatic', 0.60613580357031549),
#  ('peoples', 0.60613580357031549),
#  ('dealing', 0.60517840761398811),
#  ('fine', 0.60496962268013299),
#  ('tap', 0.60391604683200273),
#  ('trio', 0.60157998703445481),
#  ('russell', 0.60120968523425966),
#  ('figures', 0.60077386042893011),
#  ('ward', 0.60005675749393339),
#  ('shine', 0.59911823091166894),
#  ('brady', 0.59911823091166894),
#  ('job', 0.59845562125168661),
#  ('satisfied', 0.59652034487087369),
#  ('river', 0.59637962862495086),
#  ('brown', 0.595773016534769),
#  ('believable', 0.59566072133302495),
#  ('always', 0.59470710774669278),
#  ('bound', 0.59470710774669278),
#  ('cook', 0.5916777203950857),
#  ('claire', 0.59136448625000293),
#  ('broadway', 0.59033768669372433),
#  ('anna', 0.58778666490211906),
#  ('peace', 0.58628403501758408),
#  ('visually', 0.58539431926349916),
#  ('falk', 0.58525821854876026),
#  ('morality', 0.58525821854876026),
#  ('growing', 0.58466653756587539),
#  ('stood', 0.58314628534561685),
#  ('experiences', 0.58314628534561685),
#  ('touch', 0.58122926435596001),
#  ('lives', 0.5810976767513224),
#  ('hall', 0.58081799558602576),
#  ('kubrick', 0.58066919713325493),
#  ('timing', 0.58047401805583243),
#  ('expressions', 0.57981849525294216),
#  ('struggles', 0.57981849525294216),
#  ('authentic', 0.57848427223980559),
#  ('helen', 0.57763429343810091),
#  ('pre', 0.57700753064729182),
#  ('young', 0.57574343563445074),
#  ('quirky', 0.5753641449035618),
#  ('inner', 0.57454143815209846),
#  ('mexico', 0.57443087372056334),
#  ('clint', 0.57380042292737909),
#  ('sisters', 0.57286101468544337),
#  ('realism', 0.57226528899949558),
#  ('personalities', 0.5720692490067093),
#  ('french', 0.5720692490067093),
#  ('adventures', 0.57113222999698177),
#  ('surprises', 0.57113222999698177),
#  ('overcome', 0.5697681593994407),
#  ('timothy', 0.56953322459276867),
#  ('war', 0.56919624059631946),
#  ('tales', 0.56909453188996639),
#  ('civil', 0.5679840376059393),
#  ('countries', 0.56737779327091187),
#  ('streep', 0.56710645966458029),
#  ('tradition', 0.56685345523565323),
#  ('oliver', 0.56673325570428668),
#  ('australia', 0.56580775818334383),
#  ('understanding', 0.56531380905006046),
#  ('players', 0.56509525370004821),
#  ('knowing', 0.56489284503626647),
#  ('rogers', 0.56421349718405212),
#  ('howard', 0.56411692081621423),
#  ('variety', 0.56368911332305849),
#  ('suspenseful', 0.56368911332305849),
#  ('true', 0.56281525180810066),
#  ('jr', 0.56220982311246936),
#  ('psychological', 0.56108745854687891),
#  ('grand', 0.55961578793542266),
#  ('sent', 0.55961578793542266),
#  ('odds', 0.55961578793542266),
#  ('wealth', 0.55961578793542266),
#  ('overwhelming', 0.55961578793542266),
#  ('performing', 0.55961578793542266),
#  ('reminiscent', 0.55961578793542266),
#  ('branagh', 0.55961578793542266),
#  ('brothers', 0.55891181043362848),
#  ('david', 0.55693122256475369),
#  ('generation', 0.55628799784274796),
#  ('grow', 0.55612538299565417),
#  ('survival', 0.55594605904646033),
#  ('mainstream', 0.55574731115750231),
#  ('dick', 0.55431073570572953),
#  ('charm', 0.55288175575407861),
#  ('kirk', 0.55278982286502287),
#  ('twists', 0.55244729845681018),
#  ('gangster', 0.55206858230003986),
#  ('jeff', 0.55179306225421365),
#  ('family', 0.55116244510065526),
#  ('tend', 0.55053307336110335),
#  ('thanks', 0.55049088015842218),
#  ('world', 0.54785395456674801),
#  ('sutherland', 0.54743536937855164),
#  ('life', 0.5474313348347879),
#  ('disc', 0.54654370636806993),
#  ('bug', 0.54654370636806993),
#  ('tribute', 0.5455111817538808),
#  ('europe', 0.54522705048332309),
#  ('sacrifice', 0.54430155296238014),
#  ('color', 0.54405127139431109),
#  ('superior', 0.54333490233128523),
#  ('york', 0.54318235866536513),
#  ('pulls', 0.54266622962164945),
#  ('jackson', 0.54232429082536171),
#  ('hearts', 0.54232429082536171),
#  ('enjoy', 0.54124285135906114),
#  ('redemption', 0.54056759296472823),
#  ('madness', 0.540384426007535),
#  ('each', 0.53943454007562353),
#  ('trial', 0.5389965007326869),
#  ('greek', 0.5389965007326869),
#  ('hamilton', 0.5389965007326869),
#  ('stands', 0.5389965007326869),
#  ('faithful', 0.53773307668591508),
#  ('received', 0.5372768098531604),
#  ('jealous', 0.53714293208336406),
#  ('documentaries', 0.53714293208336406),
#  ('describes', 0.53680111016925136),
#  ('shorts', 0.53596159703753288),
#  ('different', 0.53596159703753288),
#  ('brilliance', 0.53551823635636209),
#  ('mountains', 0.53492317534505118),
#  ('dealt', 0.53408248593025787),
#  ('share', 0.53408248593025787),
#  ('providing', 0.53329847961804933),
#  ('explore', 0.53329847961804933),
#  ('series', 0.5325809226575603),
#  ('fellow', 0.5323318289869543),
#  ('loves', 0.53062825106217038),
#  ('revolution', 0.53062825106217038),
#  ('olivier', 0.53062825106217038),
#  ('roman', 0.53062825106217038),
#  ('century', 0.53002783074992665),
#  ('musical', 0.52966871156747064),
#  ('heroic', 0.52925932545482868),
#  ('temple', 0.52806743020049673),
#  ('ironically', 0.52806743020049673),
#  ('approach', 0.52806743020049673),
#  ('moves', 0.5279372642387119),
#  ('gift', 0.52702030968597136),
#  ('tells', 0.52415107836314001),
#  ('radio', 0.52394671172868779),
#  ('uncle', 0.52354439617376536),
#  ('union', 0.52324814376454787),
#  ('deep', 0.52309571635780505),
#  ('reminds', 0.52157841554225237),
#  ('famous', 0.52118841080153722),
#  ('jazz', 0.52053443789295151),
#  ('dennis', 0.51987545928590861),
#  ('shows', 0.51984406851793086),
#  ('human', 0.51951261457946041),
#  ('epic', 0.51919387343650736),
#  ('adult', 0.519167695083386),
#  ('performed', 0.5191244265806858),
#  ('demons', 0.5191244265806858),
#  ('discovered', 0.51879379341516751),
#  ('eric', 0.51879379341516751),
#  ('youth', 0.5185626062681431),
#  ('tarzan', 0.51813827061227724),
#  ('ourselves', 0.51794309153485463),
#  ('wwii', 0.51758240622887042),
#  ('passion', 0.5162164724008671),
#  ('desire', 0.51607497965213445),
#  ('pays', 0.51581316527702981),
#  ('dirty', 0.51557622652458857),
#  ('fox', 0.51557622652458857),
#  ('symbolism', 0.51546600332249293),
#  ('sympathetic', 0.51546600332249293),
#  ('attitude', 0.51530993621331933),
#  ('appearances', 0.51466440007315639),
#  ('jeremy', 0.51466440007315639),
#  ('fun', 0.51439068993048687),
#  ('south', 0.51420972175023116),
#  ('arrives', 0.51409894911095988),
#  ('present', 0.51341965894303732),
#  ('com', 0.51326167856387173),
#  ('smile', 0.51265880484765169),
#  ('visit', 0.51082562376599072),
#  ('countryside', 0.51082562376599072),
#  ('carter', 0.51082562376599072),
#  ('fits', 0.51082562376599072),
#  ('julie', 0.51082562376599072),
#  ('ring', 0.51082562376599072),
#  ('aging', 0.51082562376599072),
#  ('provided', 0.51082562376599072),
#  ('alan', 0.51082562376599072),
#  ('begins', 0.51015650363396647),
#  ('japan', 0.50900578704900468),
#  ('success', 0.50900578704900468),
#  ('accurate', 0.50895471583017893),
#  ('proud', 0.50800474742434931),
#  ('daily', 0.5075946031845443),
#  ('atmospheric', 0.50724780241810674),
#  ('karloff', 0.50724780241810674),
#  ('recently', 0.50714914903668207),
#  ('fu', 0.50704490092608467),
#  ('horrors', 0.50656122497953315),
#  ('finding', 0.50637127341661037),
#  ('lust', 0.5059356384717989),
#  ('hitchcock', 0.50574947073413001),
#  ('loyal', 0.50554856666514691),
#  ('among', 0.50334004951332734),
#  ('viewing', 0.50302139827440906),
#  ('investigation', 0.50262885656181222),
#  ('shining', 0.50262885656181222),
#  ('duo', 0.5020919437972361),
#  ('cameron', 0.5020919437972361),
#  ('finds', 0.50128303100539795),
#  ('age', 0.50084692371609452),
#  ('contemporary', 0.50077528791248915),
#  ('plays', 0.50048526470860022),
#  ('genuine', 0.50046283673044401),
#  ('frightening', 0.49995595152908684),
#  ('position', 0.49899116611898781),
#  ('continues', 0.49863035067217237),
#  ('roles', 0.49839716550752178),
#  ('individuals', 0.49824684155913052),
#  ('brought', 0.49783842823917956),
#  ('hilarious', 0.49714551986191058),
#  ('brutal', 0.49681488669639234),
#  ('appropriate', 0.49643688631389105),
#  ('dance', 0.49581998314812048),
#  ('league', 0.49578774640145024),
#  ('answers', 0.49578774640145024),
#  ('helping', 0.49578774640145024),
#  ('stunts', 0.49561620510246196),
#  ('traveling', 0.49532143723002542),
#  ('thoroughly', 0.49414593456733524),
#  ('james', 0.4934338810541215),
#  ('depicted', 0.49317068852726992),
#  ('honor', 0.49247648509779424),
#  ('combination', 0.49247648509779424),
#  ('differences', 0.49247648509779424),
#  ('fully', 0.49213349075383811),
#  ('tracy', 0.49159426183810306),
#  ('battles', 0.49140753790888908),
#  ('possibility', 0.49112055268665822),
#  ('romance', 0.4901589869574316),
#  ('initially', 0.49002249613622745),
#  ('happy', 0.4898997500608791),
#  ('crime', 0.48977221456815834),
#  ('singing', 0.4893852925281213),
#  ('especially', 0.48901267837860624),
#  ('necessary', 0.48798613179616795),
#  ('hugh', 0.48729512635579658),
#  ('detail', 0.48609484250827351),
#  ('companion', 0.48550781578170082),
#  ('desperation', 0.48550781578170082),
#  ('julia', 0.48550781578170082),
#  ('san', 0.48550781578170082),
#  ('guide', 0.48550781578170082),
#  ('strongly', 0.48460242866688824),
#  ('losing', 0.48460242866688824),
#  ('pictures', 0.48285177172358451),
#  ('humanity', 0.48265474679929443),
#  ('drama', 0.48221998493060503),
#  ('intrigue', 0.48183808689273838),
#  ('cuba', 0.48183808689273838),
#  ('warming', 0.48183808689273838),
#  ('nonetheless', 0.48183808689273838),
#  ('shakespeare', 0.47873730921449009),
#  ('broadcast', 0.47849024312305422),
#  ('nine', 0.47803580094299974),
#  ('settings', 0.47743860773325364),
#  ('history', 0.47732966933780852),
#  ('ordinary', 0.47725880012690741),
#  ('trade', 0.47692407209030935),
#  ('episode', 0.47627324225933099),
#  ('official', 0.47608267532211779),
#  ('primary', 0.47608267532211779),
#  ('role', 0.47520268270188676),
#  ('spirit', 0.47477690799839323),
#  ('grey', 0.47409361449726067),
#  ('ways', 0.47323464982718205),
#  ('piano', 0.47260441094579297),
#  ('cup', 0.47260441094579297),
#  ('sinister', 0.47198579044972683),
#  ('reveal', 0.47171449364936496),
#  ('max', 0.47150852042515579),
#  ('vicious', 0.47000362924573563),
#  ('genuinely', 0.46871413841586385),
#  ('familiar', 0.46759688921517062),
#  ('hatred', 0.46734051182625186),
#  ('mistaken', 0.46702300110759781),
#  ('dream', 0.46608972992459924),
#  ('challenge', 0.46608972992459924),
#  ('crisis', 0.46575733836428446),
#  ('photographed', 0.46488852857896512),
#  ('bird', 0.46430560813109778),
#  ('critics', 0.46430560813109778),
#  ('machines', 0.46430560813109778),
#  ('born', 0.46411383518967209),
#  ('detective', 0.4636633473511525),
#  ('higher', 0.46328467899699055),
#  ('inevitable', 0.46262352194811296),
#  ('remains', 0.46262352194811296),
#  ('soviet', 0.4618180446592961),
#  ('dated', 0.46155457475920791),
#  ('ryan', 0.46134556650262099),
#  ('african', 0.46112595521371813),
#  ('smaller', 0.46081520319132935),
#  ('techniques', 0.46052488529119184),
#  ('information', 0.46034171833399862),
#  ('deserved', 0.45999798712841444),
#  ('francisco', 0.45953232937844013),
#  ('tour', 0.45953232937844013),
#  ('lynch', 0.45953232937844013),
#  ('cynical', 0.45953232937844013),
#  ('spielberg', 0.45953232937844013),
#  ('struggle', 0.45911782160048453),
#  ('language', 0.45902121257712653),
#  ('treasure', 0.45886588483527962),
#  ('reality', 0.45884499688866842),
#  ('visual', 0.45823514408822852),
#  ('warner', 0.45724137763188427),
#  ('social', 0.45720078250735313),
#  ('hidden', 0.45675840249571492),
#  ('breaking', 0.45601738727099561),
#  ('sometimes', 0.45563021171182794),
#  ('modern', 0.45500247579345005),
#  ('planned', 0.45425527227759638),
#  ('surfing', 0.45425527227759638),
#  ('surprised', 0.4534409399850382),
#  ('follows', 0.45245361754408348),
#  ('john', 0.4520909494482197),
#  ('defeat', 0.45198512374305722),
#  ('mixed', 0.45198512374305722),
#  ('welcome', 0.45198512374305722),
#  ('justice', 0.45142724367280018),
#  ('years', 0.44991687067899816),
#  ('closer', 0.44973793178615257),
#  ('presents', 0.44973793178615257),
#  ('popular', 0.44944490222469896),
#  ('chief', 0.44895022004790319),
#  ('keeps', 0.44835667273747731),
#  ('shadows', 0.44802472252696035),
#  ('discovery', 0.44802472252696035),
#  ('closely', 0.44701411102103689),
#  ('segments', 0.44701411102103689),
#  ('lose', 0.44658335503763702),
#  ('caine', 0.44628710262841953),
#  ('caught', 0.44610275383999071),
#  ('hamlet', 0.44558510189758965),
#  ('chinese', 0.44507424620321018),
#  ('birth', 0.44368632092836219),
#  ('represents', 0.44320543609101143),
#  ('puts', 0.44279106572085081),
#  ('visuals', 0.44183275227903923),
#  ('web', 0.44183275227903923),
#  ('fame', 0.44183275227903923),
#  ('criminal', 0.4412745608048752),
#  ('minor', 0.4409224199448939),
#  ('jon', 0.44086703515908027),
#  ('restaurant', 0.44031183943833246),
#  ('de', 0.43983275161237217),
#  ('flaws', 0.43983275161237217),
#  ('searching', 0.4393666597838457),
#  ('rap', 0.43891304217570443),
#  ('light', 0.43884433018199892),
#  ('elizabeth', 0.43872232986464682),
#  ('marry', 0.43861731542506488),
#  ('learned', 0.43825493093115531),
#  ('oz', 0.43825493093115531),
#  ('controversial', 0.43825493093115531),
#  ('slowly', 0.43785660389939979),
#  ('liked', 0.43738856743750243),
#  ('bridge', 0.43721380642274466),
#  ('wayne', 0.43721380642274466),
#  ('comedic', 0.43721380642274466),
#  ('thrilling', 0.43721380642274466),
#  ('married', 0.43658501682196887),
#  ('nazi', 0.4361020775700542),
#  ('murder', 0.4353180712578455),
#  ('physical', 0.4353180712578455),
#  ('johnny', 0.43483971678806865),
#  ('michelle', 0.43445264498141672),
#  ('wallace', 0.43403848055222038),
#  ('silent', 0.43395706390247063),
#  ('comedies', 0.43395706390247063),
#  ('played', 0.43387244114515305),
#  ('international', 0.43363598507486073),
#  ...]

# %%
# words most frequently seen in a review with a "NEGATIVE" label
list(reversed(pos_neg_ratios.most_common()))[0:30]

# Note: Above is the code Andrew uses in his solution video, 
#       so we've included it here to avoid confusion.
#       If you explore the documentation for the Counter class, 
#       you will see you could also find the 30 least common
#       words like this: pos_neg_ratios.most_common()[:-31:-1]
# Out:
# [('boll', -4.9698132995760007),
#  ('uwe', -4.6249728132842707),
#  ('seagal', -3.6441435602725449),
#  ('unwatchable', -3.2580965380214821),
#  ('stinker', -3.2088254890146994),
#  ('mst', -2.9502698994772336),
#  ('incoherent', -2.9368917735310576),
#  ('unfunny', -2.6922395950755678),
#  ('waste', -2.6193845640165536),
#  ('blah', -2.5704288232261625),
#  ('horrid', -2.4849066497880004),
#  ('pointless', -2.4553061800117097),
#  ('atrocious', -2.4259083090260445),
#  ('redeeming', -2.3682390632154826),
#  ('prom', -2.3608540011180215),
#  ('drivel', -2.3470368555648795),
#  ('lousy', -2.3075726345050849),
#  ('worst', -2.2869878961803778),
#  ('laughable', -2.2643638801738479),
#  ('awful', -2.2271942470274348),
#  ('poorly', -2.2207550747464135),
#  ('wasting', -2.2046046846338418),
#  ('remotely', -2.1972245773362196),
#  ('existent', -2.0794415416798357),
#  ('boredom', -1.9951003932460849),
#  ('miserably', -1.9924301646902063),
#  ('sucks', -1.9870682215488209),
#  ('uninspired', -1.9832976811269336),
#  ('lame', -1.981767458946166),
#  ('insult', -1.9783454248084671)]

# %% [markdown]
# # End of Project 1.
# ## Watch the next video to see Andrew's solution, then continue on to the next lesson.
#
# # Transforming Text into Numbers<a id='lesson_3'></a>
# The cells here include code Andrew shows in the next video. We've included it so you can run the code along with the video without having to type in everything.

# %%
from IPython.display import Image

review = "This was a horrible, terrible movie."

Image(filename='sentiment_network.png')

# %%
review = "The movie was excellent"

Image(filename='sentiment_network_pos.png')

# %% [markdown]
# # Project 2: Creating the Input/Output Data<a id='project_2'></a>
#
# **TODO:** Create a [set](https://docs.python.org/3/tutorial/datastructures.html#sets) named `vocab` that contains every word in the vocabulary.

# %%
# TODO: Create set named "vocab" containing all of the words from all of the reviews
vocab = set(total_counts.keys())

# %% [markdown]
# Run the following cell to check your vocabulary size. If everything worked correctly, it should print **74074**

# %%
vocab_size = len(vocab)
print(vocab_size)
# Out:
# 74074

# %% [markdown]
# Take a look at the following image. It represents the layers of the neural network you'll be building throughout this notebook. `layer_0` is the input layer, `layer_1` is a hidden layer, and `layer_2` is the output layer.

# %%
from IPython.display import Image
Image(filename='sentiment_network_2.png')

# %% [markdown]
# **TODO:** Create a numpy array called `layer_0` and initialize it to all zeros. You will find the [zeros](https://docs.scipy.org/doc/numpy/reference/generated/numpy.zeros.html) function particularly helpful here. Be sure you create `layer_0` as a 2-dimensional matrix with 1 row and `vocab_size` columns.

# %%
# TODO: Create layer_0 matrix with dimensions 1 by vocab_size, initially filled with zeros
layer_0 = np.zeros((1, vocab_size))

# %% [markdown]
# Run the following cell. It should display `(1, 74074)`

# %%
layer_0.shape
# Out:
# (1, 74074)

# %%
from IPython.display import Image
Image(filename='sentiment_network.png')

# %% [markdown]
# `layer_0` contains one entry for every word in the vocabulary, as shown in the above image. We need to make sure we know the index of each word, so run the following cell to create a lookup table that stores the index of every word.

# %%
# Create a dictionary of words in the vocabulary mapped to index positions
# (to be used in layer_0)
word2index = {}
for i,word in enumerate(vocab):
    word2index[word] = i
    
# display the map of words to indices
word2index
# Out:
# {'': 0,
#  'hammiest': 1,
#  'fabinder': 3,
#  'inning': 4,
#  'soetman': 5,
#  'alcoholically': 6,
#  'tully': 7,
#  'unfathomable': 30936,
#  'ideal': 61668,
#  'normals': 8,
#  'herlie': 9,
#  'drovers': 10,
#  'pyasa': 11,
#  'corsets': 56932,
#  'acceptably': 12,
#  'uranus': 13,
#  'agns': 14,
#  'girlfriend': 15,
#  'tomato': 16,
#  'youknowwhat': 17,
#  'domesticity': 18,
#  'pinks': 61671,
#  'scotched': 20,
#  'move': 72667,
#  'greatest': 21,
#  'barret': 22,
#  'tiredness': 10488,
#  'nekromantik': 23,
#  'relationsip': 61675,
#  'larissa': 25,
#  'geoffery': 71313,
#  'gentile': 27,
#  'tideland': 28,
#  'bamboo': 29,
#  'expired': 30,
#  'picot': 31,
#  'keymaster': 32,
#  'lize': 33,
#  'gemser': 34,
#  'raiding': 35,
#  'goatee': 37,
#  'blowjobs': 61677,
#  'incorrectly': 38,
#  'gills': 39,
#  'pneumonia': 40,
#  'nobuhiro': 41,
#  'toothed': 61678,
#  'protege': 48,
#  'fisher': 44,
#  'henceforth': 45,
#  'gubbels': 46,
#  'toe': 47,
#  'sommersault': 49,
#  'kroko': 52,
#  'diamiter': 51,
#  'handicapped': 53,
#  'filmcritics': 54,
#  'february': 55,
#  'neidhart': 56,
#  'gillies': 57,
#  'evilmaker': 58,
#  'lawyers': 59,
#  'revelry': 61,
#  'hirarala': 62,
#  'kristensen': 63,
#  'panettiere': 64,
#  'understandably': 24664,
#  'swell': 63373,
#  'leire': 65,
#  'shanty': 66,
#  'mines': 67,
#  'kilmer': 36794,
#  'psychologies': 70,
#  'unspecific': 71,
#  'differential': 72,
#  'wharf': 76,
#  'peeked': 75,
#  'irk': 49277,
#  'portable': 77,
#  'lessen': 78,
#  'miscreant': 79,
#  'sarne': 81,
#  'warrios': 82,
#  'anykind': 83,
#  'cresta': 84,
#  'minigenre': 68723,
#  'fleet': 85,
#  'hehe': 86,
#  'paragon': 89,
#  'stanze': 90,
#  'blyton': 24666,
#  'dally': 93,
#  'darlington': 56860,
#  'kramden': 61646,
#  'reiterated': 61689,
#  'bantam': 69077,
#  'site': 94,
#  'disinherits': 95,
#  'stereos': 96,
#  'kimono': 99,
#  'thuggee': 98,
#  'zabrinskie': 100,
#  'syrianna': 101,
#  'casualty': 102,
#  'len': 72804,
#  'hinterlands': 68667,
#  'accessed': 103,
#  'gehrig': 104,
#  'selznick': 105,
#  'wims': 106,
#  'kiddin': 49766,
#  'tenterhooks': 107,
#  'hood': 108,
#  'desaturate': 12424,
#  'fubar': 109,
#  'tuff': 110,
#  'otooles': 111,
#  'survey': 49288,
#  'manity': 36802,
#  'commercialization': 114,
#  'detonation': 115,
#  'repainting': 116,
#  'pimlico': 117,
#  'berth': 61694,
#  'forshadowed': 119,
#  'minot': 49290,
#  'enlisting': 36805,
#  'rowdies': 120,
#  'epiphany': 121,
#  'mada': 122,
#  'poodlesque': 123,
#  'misbehaves': 127,
#  'ryan': 128,
#  'backroad': 129,
#  'playrights': 131,
#  'hugs': 22635,
#  'dictioary': 132,
#  'kanes': 133,
#  'climes': 134,
#  'dreamworld': 135,
#  'arli': 136,
#  'has': 137,
#  'garuntee': 138,
#  'deriviative': 139,
#  'primate': 141,
#  'plagues': 142,
#  'grifter': 143,
#  'extreamly': 144,
#  'adjutant': 145,
#  'smit': 146,
#  'biologist': 147,
#  'cinderella': 148,
#  'rosenman': 149,
#  'costy': 152,
#  'fia': 151,
#  'defintely': 153,
#  'qualitative': 155,
#  'yelnats': 156,
#  'hocking': 157,
#  'station': 158,
#  'quotidien': 159,
#  'regards': 160,
#  'soul': 161,
#  'showgirl': 162,
#  'chunder': 163,
#  'personnel': 164,
#  'splashes': 24,
#  'atheist': 49294,
#  'donnie': 165,
#  'condominium': 72646,
#  'harni': 166,
#  'microbudget': 49295,
#  'couches': 172,
#  'catalyst': 168,
#  'vulgar': 170,
#  'burma': 173,
#  'splash': 26,
#  'mannheim': 61703,
#  'osterwald': 66390,
#  'holograms': 176,
#  'huppertz': 175,
#  'cugat': 177,
#  'vi': 49300,
#  'recollected': 27426,
#  'jovovich': 178,
#  'japery': 31718,
#  'screenwriting': 181,
#  'december': 182,
#  'selected': 183,
#  'faze': 184,
#  'colonised': 185,
#  'rushed': 186,
#  'raider': 61706,
#  'extroverts': 188,
#  'claremont': 189,
#  'specifically': 190,
#  'rapt': 49306,
#  'hiralal': 192,
#  'upbringing': 193,
#  'kants': 194,
#  'valette': 195,
#  'slayings': 197,
#  'gettaway': 199,
#  'basilisk': 200,
#  'troble': 201,
#  'torque': 202,
#  'ball': 203,
#  'lonelier': 204,
#  'glimpses': 205,
#  'makeovers': 55325,
#  'rigg': 210,
#  'roasted': 209,
#  'mea': 211,
#  'emilia': 213,
#  'watcxh': 68729,
#  'ethnical': 214,
#  'belly': 215,
#  'wallraff': 12437,
#  'standard': 216,
#  'millenia': 219,
#  'aznar': 218,
#  'defecate': 220,
#  'oversupporting': 221,
#  'spagnolo': 222,
#  'criminally': 223,
#  'epics': 225,
#  'brown': 72300,
#  'zenda': 226,
#  'carachters': 227,
#  'burbling': 228,
#  'lurches': 230,
#  'risibly': 231,
#  'oscillating': 233,
#  'provincialism': 234,
#  'tactless': 235,
#  'erudite': 12442,
#  'mopped': 238,
#  'dash': 237,
#  'spangled': 239,
#  'farrell': 240,
#  'docudrama': 241,
#  'hotels': 242,
#  'coordinated': 36,
#  'parsi': 31537,
#  'deft': 24686,
#  'patent': 244,
#  'crystina': 52079,
#  'kurtwood': 68936,
#  'upmanship': 63969,
#  'shakedown': 245,
#  'diffuses': 246,
#  'proponent': 247,
#  'anansie': 248,
#  'ruff': 70910,
#  'meet': 250,
#  'truant': 251,
#  'royalties': 252,
#  'security': 253,
#  'burry': 255,
#  'locates': 256,
#  'shayamalan': 257,
#  'mantagna': 45945,
#  'borden': 263,
#  'westerner': 268,
#  'harmonise': 265,
#  'eliminate': 262,
#  'teethed': 264,
#  'flatlined': 266,
#  'pr': 267,
#  'goldeneye': 270,
#  'unacquainted': 271,
#  'zd': 272,
#  'effette': 274,
#  'collide': 275,
#  'forecasts': 276,
#  'ghoststory': 66524,
#  'margins': 35181,
#  'goats': 277,
#  'pigs': 278,
#  'dilly': 279,
#  'chagrined': 281,
#  'basin': 42,
#  'spang': 283,
#  'knickers': 284,
#  'prjean': 285,
#  'vepsaian': 61722,
#  'sac': 286,
#  'healthful': 287,
#  'worest': 288,
#  'bankrolled': 289,
#  'podiatrist': 290,
#  'severally': 291,
#  'durang': 292,
#  'aptly': 293,
#  'guested': 294,
#  'banjoes': 295,
#  'chaise': 43,
#  'braincell': 297,
#  'timothy': 36839,
#  'comiccon': 302,
#  'libber': 299,
#  'noriyuki': 300,
#  'zealot': 301,
#  'eva': 303,
#  'persuasion': 49329,
#  'happend': 306,
#  'freemasons': 305,
#  'discursive': 307,
#  'widdered': 308,
#  'pentagram': 309,
#  'capeshaw': 310,
#  'ooky': 311,
#  'peckinpaugh': 61726,
#  'landscaped': 312,
#  'nadanova': 316,
#  'necktie': 317,
#  'nepal': 315,
#  'bitten': 320,
#  'treads': 322,
#  'monkeys': 50,
#  'colts': 67616,
#  'sirs': 325,
#  'anjolina': 326,
#  'digitised': 327,
#  'gissing': 330,
#  'viertel': 44299,
#  'mirthless': 331,
#  'juha': 332,
#  'eroticism': 28943,
#  'range': 15304,
#  'suffocating': 333,
#  'murkier': 334,
#  'unbothersome': 335,
#  'rewards': 336,
#  'sirico': 337,
#  'skirt': 339,
#  'ataque': 24700,
#  'szwarc': 340,
#  'hijackers': 341,
#  'gashuin': 342,
#  'btch': 343,
#  'godby': 344,
#  'tsui': 49336,
#  'comprehensively': 346,
#  'pringle': 347,
#  'mangy': 348,
#  'commitophobe': 349,
#  'shelf': 350,
#  'cuddling': 351,
#  'whitman': 49339,
#  'massacrenot': 352,
#  'placed': 353,
#  'wedding': 355,
#  'fairmindedness': 49340,
#  'cineastes': 356,
#  'walters': 357,
#  'aristidis': 358,
#  'pleiades': 51750,
#  'kurita': 359,
#  'neweyes': 360,
#  'rejoin': 361,
#  'kinekor': 362,
#  'kassovitz': 61734,
#  'booking': 363,
#  'vegetable': 28706,
#  'buffer': 364,
#  'salaciousness': 365,
#  'independence': 366,
#  'odyssey': 368,
#  'synonymous': 370,
#  'sturgess': 36849,
#  'gloss': 371,
#  'ltr': 372,
#  'qualifying': 373,
#  'dysphoria': 376,
#  'mathis': 375,
#  'surreptitiously': 377,
#  'tono': 378,
#  'mcmurphy': 66422,
#  'veiled': 380,
#  'ikea': 382,
#  'foils': 383,
#  'austreheim': 384,
#  'macdougall': 385,
#  'almost': 24708,
#  'outer': 386,
#  'germann': 387,
#  'zacaras': 12462,
#  'deciphered': 388,
#  'nudging': 389,
#  'zen': 390,
#  'taz': 392,
#  'lavoura': 396,
#  'woopie': 399,
#  'nerukku': 395,
#  'disgusted': 397,
#  'throwaway': 398,
#  'kinki': 400,
#  'uttter': 401,
#  'affection': 403,
#  'predeccesor': 61739,
#  'distribution': 70467,
#  'scalia': 404,
#  'awoke': 406,
#  'marietta': 24713,
#  'confedercy': 2218,
#  'proverbs': 49346,
#  'midi': 407,
#  'stuningly': 408,
#  'zellweger': 61742,
#  'afilm': 409,
#  'vanning': 412,
#  'elmore': 24717,
#  'lightfoot': 413,
#  'hmv': 31225,
#  'synthesizers': 414,
#  'dahmers': 415,
#  'mobster': 416,
#  'microcosm': 417,
#  'corrodes': 418,
#  'caca': 419,
#  'telugu': 421,
#  'bathetic': 422,
#  'brull': 425,
#  'alzheimers': 424,
#  'slumber': 49349,
#  'schizophreniac': 426,
#  'quizzes': 427,
#  'depression': 429,
#  'sharecropper': 430,
#  'hashes': 431,
#  'empower': 434,
#  'katie': 433,
#  'catwalk': 49353,
#  'howlers': 435,
#  'nastier': 437,
#  'decodes': 440,
#  'titillates': 441,
#  'soong': 73,
#  'pure': 442,
#  'blather': 443,
#  'hikers': 444,
#  'conjured': 448,
#  'phir': 454,
#  'jurgen': 61749,
#  'blowjob': 450,
#  'yetians': 452,
#  'leachman': 453,
#  'dilation': 62606,
#  'dufus': 455,
#  'gravestones': 456,
#  'happier': 457,
#  'dareus': 458,
#  'surrealistic': 459,
#  'warnercolor': 460,
#  'bgs': 464,
#  'commissary': 462,
#  'gigolo': 57237,
#  'cinch': 465,
#  'heeeeeere': 466,
#  'jutland': 467,
#  'pulpy': 42165,
#  'lattuada': 66304,
#  'consulting': 468,
#  'trolley': 61388,
#  'foreclosed': 469,
#  'urdu': 470,
#  'british': 74,
#  'autographs': 471,
#  'gaffe': 472,
#  'raj': 473,
#  'tits': 474,
#  'dykes': 475,
#  'swordfight': 476,
#  'superlow': 478,
#  'frances': 479,
#  'vassar': 480,
#  'laude': 481,
#  'stormy': 482,
#  'snipping': 483,
#  'samhain': 486,
#  'piglet': 487,
#  'denard': 488,
#  'avoiding': 489,
#  'tuvoc': 49362,
#  'intercoms': 492,
#  'swathed': 12481,
#  'flavorless': 80,
#  'mystified': 493,
#  'trentin': 500,
#  'disappearances': 495,
#  'epcot': 501,
#  'guitars': 36866,
#  'hither': 498,
#  'lamarr': 55144,
#  'satirise': 503,
#  'sprout': 24730,
#  'casings': 504,
#  'truculent': 505,
#  'morely': 506,
#  'paragraphs': 507,
#  'agonizingly': 508,
#  'improbable': 24734,
#  'incorporeal': 509,
#  'rustler': 49366,
#  'manley': 510,
#  'macallum': 511,
#  'reinstall': 512,
#  'possessions': 513,
#  'preparing': 514,
#  'dar': 62030,
#  'wilbur': 516,
#  'attal': 517,
#  'vivienne': 518,
#  'donnovan': 520,
#  'avarice': 530,
#  'freeloader': 526,
#  'sheeta': 525,
#  'slaughterhouse': 524,
#  'mastrontonio': 527,
#  'spores': 528,
#  'lf': 533,
#  'exhumed': 531,
#  'preventing': 532,
#  'insofar': 31159,
#  'gander': 534,
#  'reveres': 61758,
#  'agreeable': 536,
#  'undramatic': 36870,
#  'daft': 537,
#  'concessions': 538,
#  'embodies': 539,
#  'iikes': 540,
#  'spellbinding': 541,
#  'outdoorsman': 542,
#  'investigating': 12489,
#  'eliciting': 544,
#  'studies': 546,
#  'neurosis': 547,
#  'plaid': 548,
#  'assent': 58025,
#  'preyer': 549,
#  'affronting': 550,
#  'corby': 12492,
#  'dubai': 551,
#  'odeon': 36874,
#  'undocumented': 44307,
#  'hansel': 553,
#  'motherf': 554,
#  'frack': 27519,
#  'olen': 560,
#  'weasely': 558,
#  'mendanassos': 87,
#  'lawsuits': 559,
#  'suffer': 562,
#  'wanting': 564,
#  'storekeeper': 70298,
#  'phatasms': 571,
#  'whizz': 566,
#  'simulator': 567,
#  'freejack': 568,
#  'chiefly': 569,
#  'eeks': 570,
#  'mollys': 74019,
#  'nerds': 574,
#  'freakiness': 575,
#  'polygon': 91,
#  'leathal': 60111,
#  'amuck': 576,
#  'maitlan': 577,
#  'unscrupulously': 578,
#  'popcorn': 49380,
#  'bowfinger': 579,
#  'blunder': 580,
#  'catatonia': 581,
#  'fearsome': 24742,
#  'dwindle': 71505,
#  'mulan': 583,
#  'bittersweetness': 585,
#  'calibrated': 586,
#  'intention': 587,
#  'hendersons': 92,
#  'seriesall': 588,
#  'magowan': 590,
#  'wonders': 591,
#  'lemorande': 592,
#  'indra': 594,
#  'novarro': 12502,
#  'pathologize': 596,
#  'actioners': 597,
#  'team': 61766,
#  'dissappoint': 598,
#  'credit': 599,
#  'sthetic': 600,
#  'mcconnell': 603,
#  'cycles': 604,
#  'hagia': 606,
#  'shoddiness': 607,
#  'shamroy': 609,
#  'fitness': 61769,
#  'sadler': 611,
#  'buba': 612,
#  'fireplace': 72814,
#  'ska': 614,
#  'mahmoud': 615,
#  'coordinator': 616,
#  'pauly': 617,
#  'saddos': 619,
#  'cambridge': 622,
#  'sanitised': 63142,
#  'plesantly': 626,
#  'overrate': 624,
#  'sprezzatura': 625,
#  'streetlamp': 627,
#  'responding': 628,
#  'rstj': 629,
#  'manufacturing': 631,
#  'continual': 69326,
#  'strangers': 633,
#  'rumbles': 635,
#  'francescoantonio': 636,
#  'munsters': 637,
#  'lwensohn': 638,
#  'underwhelming': 639,
#  'groupies': 68247,
#  'mordrid': 49386,
#  'insipid': 72033,
#  'adamant': 640,
#  'sarpeidon': 641,
#  'aguirre': 642,
#  'counting': 643,
#  'lou': 644,
#  'wishes': 36885,
#  'colomb': 5678,
#  'primitives': 646,
#  'burst': 647,
#  'assorted': 648,
#  'recklessly': 649,
#  'constricted': 650,
#  'soxers': 651,
#  'whythey': 652,
#  'cleavage': 653,
#  'fudged': 654,
#  'kaempfen': 61775,
#  'mmt': 655,
#  'decisively': 656,
#  'toning': 660,
#  'peplum': 658,
#  'duvivier': 97,
#  'nasty': 663,
#  'insides': 664,
#  'sellick': 665,
#  'whew': 666,
#  'instances': 55451,
#  'welliver': 671,
#  'gangly': 669,
#  'director': 670,
#  'mozambique': 672,
#  'replicated': 61778,
#  'shawn': 673,
#  'blow': 674,
#  'receiving': 675,
#  'redistribute': 676,
#  'beneficial': 677,
#  'communinity': 679,
#  'frays': 62273,
#  'fastway': 680,
#  'desposal': 681,
#  'tiburon': 682,
#  'chirpy': 683,
#  'worthlessness': 684,
#  'lugosiyet': 685,
#  'sose': 686,
#  'shte': 687,
#  'bowels': 52105,
#  'whoopee': 689,
#  'chinnery': 68546,
#  'chicken': 690,
#  'signed': 68429,
#  'detected': 691,
#  'critters': 692,
#  'mallow': 24755,
#  'buttock': 694,
#  'tends': 695,
#  'yellows': 697,
#  'whatsoever': 698,
#  'hired': 700,
#  'vampires': 67711,
#  'repetitive': 702,
#  'hammily': 703,
#  'preps': 704,
#  'juvenilia': 72558,
#  'jackets': 705,
#  'pacman': 706,
#  'im': 708,
#  'nicolette': 709,
#  'rea': 710,
#  'evanescent': 711,
#  'clearheaded': 712,
#  'uncommon': 713,
#  'chirping': 715,
#  'convictions': 716,
#  'formally': 717,
#  'underling': 53910,
#  'discourses': 73858,
#  'shys': 719,
#  'collison': 720,
#  'absorbing': 49865,
#  'denounces': 721,
#  'storming': 722,
#  'turbid': 724,
#  'stroud': 727,
#  'sauraus': 728,
#  'mcnealy': 730,
#  'paused': 731,
#  'centaurion': 732,
#  'cliche': 733,
#  'debates': 49399,
#  'nathaniel': 736,
#  'keeps': 735,
#  'shadow': 737,
#  'cereal': 738,
#  'blossoming': 740,
#  'fakely': 742,
#  'treatise': 24760,
#  'timmy': 744,
#  'lindseys': 745,
#  'jazmine': 112,
#  'phi': 750,
#  'liking': 748,
#  'kutcher': 749,
#  'sm': 751,
#  'hustlers': 24762,
#  'fireballs': 754,
#  'vaseline': 755,
#  'cartons': 756,
#  'speedman': 757,
#  'daltry': 760,
#  'gladaitor': 761,
#  'booted': 72534,
#  'stacey': 762,
#  'hallie': 763,
#  'haply': 764,
#  'interceptors': 765,
#  'korman': 766,
#  'cassie': 767,
#  'arggh': 49404,
#  'dee': 770,
#  'destined': 113,
#  'mallrats': 68993,
#  'fallacious': 772,
#  'knockdown': 773,
#  'european': 774,
#  'sequituurs': 775,
#  'muse': 65112,
#  'colcord': 778,
#  'ramn': 62616,
#  'sensitivities': 49405,
#  'subscribes': 780,
#  'olan': 62761,
#  'dalliances': 781,
#  'joyriding': 783,
#  'peek': 784,
#  'mutates': 785,
#  'wharfs': 39538,
#  'sissily': 64833,
#  'bandmates': 118,
#  'fiercest': 786,
#  'bromell': 787,
#  'libbed': 790,
#  'lamebrained': 791,
#  'while': 792,
#  'kaif': 793,
#  'ooga': 794,
#  'victimizing': 795,
#  'whackjobs': 799,
#  'upbeat': 797,
#  'wallet': 798,
#  'emily': 800,
#  'starla': 801,
#  'krishna': 802,
#  'yokai': 803,
#  'undoing': 12531,
#  'downs': 805,
#  'idjits': 806,
#  'representation': 807,
#  'shackles': 808,
#  'bluffing': 809,
#  'antwerp': 810,
#  'gazette': 811,
#  'inslee': 812,
#  'prisinors': 814,
#  'nearest': 36902,
#  'bogdonovitch': 815,
#  'acme': 24775,
#  'attributed': 49416,
#  'turnbuckles': 816,
#  'yokia': 817,
#  'enacts': 818,
#  'intermittedly': 819,
#  'undamaged': 820,
#  'boyz': 821,
#  'bucke': 823,
#  'poach': 824,
#  'mhatre': 827,
#  'becalmed': 828,
#  'spotlighting': 11103,
#  'whoppers': 829,
#  'angelical': 830,
#  'mistresses': 831,
#  'athenean': 49419,
#  'manr': 832,
#  'converge': 833,
#  'illlinois': 834,
#  'instants': 835,
#  'steptoe': 24782,
#  'veering': 838,
#  'hickham': 837,
#  'buford': 839,
#  'gyrate': 840,
#  'translucent': 842,
#  'hits': 843,
#  'pretext': 844,
#  'speakeasy': 16165,
#  'implication': 846,
#  'ream': 847,
#  'replicating': 848,
#  'sondheim': 849,
#  'cruelity': 850,
#  'simn': 851,
#  'defamed': 852,
#  'ropsenlski': 853,
#  'atlanteans': 61256,
#  'quaid': 126,
#  'professionell': 854,
#  'zither': 855,
#  'vimbley': 856,
#  'leonidus': 857,
#  'indictable': 71509,
#  'talented': 858,
#  'reappraised': 859,
#  'diligent': 49490,
#  'cuasi': 861,
#  'vannoordlet': 863,
#  'terrore': 864,
#  'excell': 865,
#  'doubtfully': 866,
#  'retained': 867,
#  'oversimplify': 51948,
#  'overwatched': 870,
#  'yells': 72273,
#  'qualify': 871,
#  'sin': 872,
#  'skilled': 873,
#  'hito': 876,
#  'unison': 875,
#  'schedules': 61799,
#  'tolliver': 878,
#  'scepter': 879,
#  'caffeinated': 880,
#  'outpost': 881,
#  'cue': 12548,
#  'healers': 15765,
#  'pusses': 882,
#  'allegorically': 883,
#  'pixote': 66300,
#  'fuhrer': 884,
#  'fallon': 885,
#  'warring': 53382,
#  'blazers': 886,
#  'turncoats': 887,
#  'brazen': 888,
#  'torrent': 890,
#  'communicator': 49428,
#  'lazarushian': 893,
#  'spew': 46585,
#  'drainingly': 49432,
#  'fixtures': 894,
#  'fictionalization': 895,
#  'jawani': 49431,
#  'intertextuality': 896,
#  'tumbuan': 897,
#  'bigscreen': 5811,
#  'tohs': 898,
#  'roselina': 899,
#  'caught': 69744,
#  'bromwell': 900,
#  'unfoldings': 901,
#  'narrative': 902,
#  'freckle': 911,
#  'defenseless': 904,
#  'schulberg': 912,
#  'unconcious': 906,
#  'cure': 907,
#  'urinary': 908,
#  'homosexual': 909,
#  'compassionate': 910,
#  'accomplishes': 68444,
#  'spectator': 914,
#  'gaskets': 915,
#  'unqiue': 916,
#  'enslave': 917,
#  'uncompromising': 919,
#  'bluntschi': 56210,
#  'mendocino': 920,
#  'davidbathsheba': 921,
#  'lozano': 922,
#  'fatuous': 923,
#  'sidelight': 73504,
#  'nivens': 72137,
#  'constituted': 24796,
#  'tranceformers': 49440,
#  'clockers': 924,
#  'consider': 925,
#  'whittington': 927,
#  'nuristan': 928,
#  'weighill': 40310,
#  'epsilon': 24798,
#  'uncomprehension': 929,
#  'elainor': 931,
#  'carrie': 36919,
#  'robe': 933,
#  'dickie': 48404,
#  'shater': 49441,
#  'hazed': 934,
#  'reboots': 42463,
#  'herrmann': 64904,
#  'tornado': 935,
#  'beatriz': 936,
#  'tasteless': 939,
#  'rotoscopic': 940,
#  'kajawari': 942,
#  'christina': 943,
#  'greying': 944,
#  'victories': 946,
#  'regally': 947,
#  'gents': 36923,
#  'doqui': 949,
#  'seized': 52113,
#  'minnelli': 951,
#  'realist': 68920,
#  'plundered': 24802,
#  'jabs': 952,
#  'exterminator': 953,
#  'bashevis': 36926,
#  'mckinney': 955,
#  'slowish': 24803,
#  'turnings': 956,
#  'porretta': 957,
#  'section': 36932,
#  'plentiful': 959,
#  'angora': 12560,
#  'sunnys': 960,
#  'pathology': 961,
#  'ittami': 963,
#  'lita': 24805,
#  'monkeybone': 964,
#  'arghhhhh': 965,
#  'lambert': 966,
#  'devilishly': 967,
#  'jenner': 968,
#  'blameless': 2321,
#  'relegated': 66077,
#  'seo': 12562,
#  'writhing': 71880,
#  'somnolent': 36930,
#  'paramour': 40546,
#  'fails': 969,
#  'airless': 970,
#  'eyed': 971,
#  'capano': 150,
#  'catalog': 72434,
#  'amidst': 61819,
#  'rnb': 974,
#  'floodwaters': 975,
#  'composite': 977,
#  'unpolite': 978,
#  'corrective': 979,
#  'stomaching': 980,
#  'tem': 981,
#  'chattering': 983,
#  'det': 49452,
#  'medicals': 986,
#  'ofstars': 987,
#  'proceeds': 34083,
#  'leterrier': 989,
#  'twinkling': 990,
#  'gingerly': 995,
#  'hainey': 992,
#  'nuttball': 993,
#  'ramotswe': 994,
#  'belied': 154,
#  'although': 996,
#  'vegetating': 998,
#  'uncontaminated': 999,
#  'noise': 1000,
#  'cranston': 1001,
#  'interminably': 1002,
#  'muzzle': 1003,
#  'evidente': 73157,
#  ...}

# %% [markdown]
# **TODO:**  Complete the implementation of `update_input_layer`. It should count
#           how many times each word is used in the given review, and then store
#           those counts at the appropriate indices inside `layer_0`.

# %%
def update_input_layer(review):
    """ Modify the global layer_0 to represent the vector form of review.
    The element at a given index of layer_0 should represent
    how many times the given word occurs in the review.
    Args:
        review(string) - the string of the review
    Returns:
        None
    """
    global layer_0
    # clear out previous state by resetting the layer to be all 0s
    layer_0 *= 0
    
    review_word_count = Counter()
    # TODO: count how many times each word is used in the given review and store the results in layer_0 
    for word in review.split(" "):
        layer_0[0][word2index[word]] += 1

# %% [markdown]
# Run the following cell to test updating the input layer with the first review. The indices assigned may not be the same as in the solution, but hopefully you'll see some non-zero values in `layer_0`.

# %%
update_input_layer(reviews[0])
layer_0
# Out:
# array([[ 18.,   0.,   0., ...,   0.,   0.,   0.]])

# %% [markdown]
# **TODO:** Complete the implementation of `get_target_for_labels`. It should return `0` or `1`,
#           depending on whether the given label is `NEGATIVE` or `POSITIVE`, respectively.

# %%
def get_target_for_label(label):
    """Convert a label to `0` or `1`.
    Args:
        label(string) - Either "POSITIVE" or "NEGATIVE".
    Returns:
        `0` or `1`.
    """
    # TODO: Your code here
    if(label == "POSITIVE"):
        return 1
    else:
        return 0

# %% [markdown]
# Run the following two cells. They should print out`'POSITIVE'` and `1`, respectively.

# %%
labels[0]
# Out:
# 'POSITIVE'

# %%
get_target_for_label(labels[0])
# Out:
# 1

# %% [markdown]
# Run the following two cells. They should print out `'NEGATIVE'` and `0`, respectively.

# %%
labels[1]
# Out:
# 'NEGATIVE'

# %%
get_target_for_label(labels[1])
# Out:
# 0

# %% [markdown]
# # End of Project 2.
# ## Watch the next video to see Andrew's solution, then continue on to the next lesson.

# %% [markdown]
# # Project 3: Building a Neural Network<a id='project_3'></a>

# %% [markdown]
# **TODO:** We've included the framework of a class called `SentimentNetork`. Implement all of the items marked `TODO` in the code. These include doing the following:
# - Create a basic neural network much like the networks you've seen in earlier lessons and in Project 1, with an input layer, a hidden layer, and an output layer.
# - Do **not** add a non-linearity in the hidden layer. That is, do not use an activation function when calculating the hidden layer outputs.
# - Re-use the code from earlier in this notebook to create the training data (see `TODO`s in the code)
# - Implement the `pre_process_data` function to create the vocabulary for our training data generating functions
# - Ensure `train` trains over the entire corpus

# %% [markdown]
# ### Where to Get Help if You Need it
# - Re-watch earlier Udacity lectures
# - Chapters 3-5 - [Grokking Deep Learning](https://www.manning.com/books/grokking-deep-learning) - (Check inside your classroom for a discount code)

# %%
import time
import sys
import numpy as np

# Encapsulate our neural network in a class
class SentimentNetwork:
    def __init__(self, reviews,labels,hidden_nodes = 10, learning_rate = 0.1):
        """Create a SentimenNetwork with the given settings
        Args:
            reviews(list) - List of reviews used for training
            labels(list) - List of POSITIVE/NEGATIVE labels associated with the given reviews
            hidden_nodes(int) - Number of nodes to create in the hidden layer
            learning_rate(float) - Learning rate to use while training
        
        """
        # Assign a seed to our random number generator to ensure we get
        # reproducable results during development 
        np.random.seed(1)

        # process the reviews and their associated labels so that everything
        # is ready for training
        self.pre_process_data(reviews, labels)
        
        # Build the network to have the number of hidden nodes and the learning rate that
        # were passed into this initializer. Make the same number of input nodes as
        # there are vocabulary words and create a single output node.
        self.init_network(len(self.review_vocab),hidden_nodes, 1, learning_rate)

    def pre_process_data(self, reviews, labels):
        
        # populate review_vocab with all of the words in the given reviews
        review_vocab = set()
        for review in reviews:
            for word in review.split(" "):
                review_vocab.add(word)

        # Convert the vocabulary set to a list so we can access words via indices
        self.review_vocab = list(review_vocab)
        
        # populate label_vocab with all of the words in the given labels.
        label_vocab = set()
        for label in labels:
            label_vocab.add(label)
        
        # Convert the label vocabulary set to a list so we can access labels via indices
        self.label_vocab = list(label_vocab)
        
        # Store the sizes of the review and label vocabularies.
        self.review_vocab_size = len(self.review_vocab)
        self.label_vocab_size = len(self.label_vocab)
        
        # Create a dictionary of words in the vocabulary mapped to index positions
        self.word2index = {}
        for i, word in enumerate(self.review_vocab):
            self.word2index[word] = i
        
        # Create a dictionary of labels mapped to index positions
        self.label2index = {}
        for i, label in enumerate(self.label_vocab):
            self.label2index[label] = i
        
    def init_network(self, input_nodes, hidden_nodes, output_nodes, learning_rate):
        # Set number of nodes in input, hidden and output layers.
        self.input_nodes = input_nodes
        self.hidden_nodes = hidden_nodes
        self.output_nodes = output_nodes

        # Store the learning rate
        self.learning_rate = learning_rate

        # Initialize weights

        # These are the weights between the input layer and the hidden layer.
        self.weights_0_1 = np.zeros((self.input_nodes,self.hidden_nodes))
    
        # These are the weights between the hidden layer and the output layer.
        self.weights_1_2 = np.random.normal(0.0, self.output_nodes**-0.5, 
                                                (self.hidden_nodes, self.output_nodes))
        
        # The input layer, a two-dimensional matrix with shape 1 x input_nodes
        self.layer_0 = np.zeros((1,input_nodes))
    
    def update_input_layer(self,review):

        # clear out previous state, reset the layer to be all 0s
        self.layer_0 *= 0
        
        for word in review.split(" "):
            # NOTE: This if-check was not in the version of this method created in Project 2,
            #       and it appears in Andrew's Project 3 solution without explanation. 
            #       It simply ensures the word is actually a key in word2index before
            #       accessing it, which is important because accessing an invalid key
            #       with raise an exception in Python. This allows us to ignore unknown
            #       words encountered in new reviews.
            if(word in self.word2index.keys()):
                self.layer_0[0][self.word2index[word]] += 1
                
    def get_target_for_label(self,label):
        if(label == 'POSITIVE'):
            return 1
        else:
            return 0
        
    def sigmoid(self,x):
        return 1 / (1 + np.exp(-x))
    
    def sigmoid_output_2_derivative(self,output):
        return output * (1 - output)
    
    def train(self, training_reviews, training_labels):
        
        # make sure out we have a matching number of reviews and labels
        assert(len(training_reviews) == len(training_labels))
        
        # Keep track of correct predictions to display accuracy during training 
        correct_so_far = 0

        # Remember when we started for printing time statistics
        start = time.time()
        
        # loop through all the given reviews and run a forward and backward pass,
        # updating weights for every item
        for i in range(len(training_reviews)):
            
            # Get the next review and its correct label
            review = training_reviews[i]
            label = training_labels[i]
            
            #### Implement the forward pass here ####
            ### Forward pass ###

            # Input Layer
            self.update_input_layer(review)

            # Hidden layer
            layer_1 = self.layer_0.dot(self.weights_0_1)

            # Output layer
            layer_2 = self.sigmoid(layer_1.dot(self.weights_1_2))
            
            #### Implement the backward pass here ####
            ### Backward pass ###

            # Output error
            layer_2_error = layer_2 - self.get_target_for_label(label) # Output layer error is the difference between desired target and actual output.
            layer_2_delta = layer_2_error * self.sigmoid_output_2_derivative(layer_2)

            # Backpropagated error
            layer_1_error = layer_2_delta.dot(self.weights_1_2.T) # errors propagated to the hidden layer
            layer_1_delta = layer_1_error # hidden layer gradients - no nonlinearity so it's the same as the error

            # Update the weights
            self.weights_1_2 -= layer_1.T.dot(layer_2_delta) * self.learning_rate # update hidden-to-output weights with gradient descent step
            self.weights_0_1 -= self.layer_0.T.dot(layer_1_delta) * self.learning_rate # update input-to-hidden weights with gradient descent step

            # Keep track of correct predictions.
            if(layer_2 >= 0.5 and label == 'POSITIVE'):
                correct_so_far += 1
            elif(layer_2 < 0.5 and label == 'NEGATIVE'):
                correct_so_far += 1
            
            # For debug purposes, print out our prediction accuracy and speed 
            # throughout the training process. 
            elapsed_time = float(time.time() - start)
            reviews_per_second = i / elapsed_time if elapsed_time > 0 else 0
            
            sys.stdout.write("\rProgress:" + str(100 * i/float(len(training_reviews)))[:4] \
                             + "% Speed(reviews/sec):" + str(reviews_per_second)[0:5] \
                             + " #Correct:" + str(correct_so_far) + " #Trained:" + str(i+1) \
                             + " Training Accuracy:" + str(correct_so_far * 100 / float(i+1))[:4] + "%")
            if(i % 2500 == 0):
                print("")
    
    def test(self, testing_reviews, testing_labels):
        """
        Attempts to predict the labels for the given testing_reviews,
        and uses the test_labels to calculate the accuracy of those predictions.
        """
        
        # keep track of how many correct predictions we make
        correct = 0

        # we'll time how many predictions per second we make
        start = time.time()

        # Loop through each of the given reviews and call run to predict
        # its label. 
        for i in range(len(testing_reviews)):
            pred = self.run(testing_reviews[i])
            if(pred == testing_labels[i]):
                correct += 1
            
            # For debug purposes, print out our prediction accuracy and speed 
            # throughout the prediction process. 

            elapsed_time = float(time.time() - start)
            reviews_per_second = i / elapsed_time if elapsed_time > 0 else 0
            
            sys.stdout.write("\rProgress:" + str(100 * i/float(len(testing_reviews)))[:4] \
                             + "% Speed(reviews/sec):" + str(reviews_per_second)[0:5] \
                             + " #Correct:" + str(correct) + " #Tested:" + str(i+1) \
                             + " Testing Accuracy:" + str(correct * 100 / float(i+1))[:4] + "%")
    
    def run(self, review):
        """
        Returns a POSITIVE or NEGATIVE prediction for the given review.
        """
        # Run a forward pass through the network, like in the "train" function.
        
        # Input Layer
        self.update_input_layer(review.lower())

        # Hidden layer
        layer_1 = self.layer_0.dot(self.weights_0_1)

        # Output layer
        layer_2 = self.sigmoid(layer_1.dot(self.weights_1_2))
        
        # Return POSITIVE for values above greater-than-or-equal-to 0.5 in the output layer;
        # return NEGATIVE for other values
        if(layer_2[0] >= 0.5):
            return "POSITIVE"
        else:
            return "NEGATIVE"

# %% [markdown]
# Run the following cell to create a `SentimentNetwork` that will train on all but the last 1000 reviews (we're saving those for testing). Here we use a learning rate of `0.1`.

# %%
mlp = SentimentNetwork(reviews[:-1000],labels[:-1000], learning_rate=0.1)

# %% [markdown]
# Run the following cell to test the network's performance against the last 1000 reviews (the ones we held out from our training set).
#
# **We have not trained the model yet, so the results should be about 50% as it will just be guessing and there are only two possible values to choose from.**

# %%
mlp.test(reviews[-1000:],labels[-1000:])
# Out:
# Progress:99.9% Speed(reviews/sec):996.2 #Correct:500 #Tested:1000 Testing Accuracy:50.0%

# %% [markdown]
# Run the following cell to actually train the network. During training, it will display the model's accuracy repeatedly as it trains so you can see how well it's doing.

# %%
mlp.train(reviews[:-1000],labels[:-1000])
# Out:
# Progress:0.0% Speed(reviews/sec):0.0 #Correct:1 #Trained:1 Training Accuracy:100.%
# Progress:10.4% Speed(reviews/sec):152.1 #Correct:1251 #Trained:2501 Training Accuracy:50.0%
# Progress:20.8% Speed(reviews/sec):151.5 #Correct:2501 #Trained:5001 Training Accuracy:50.0%
# Progress:31.2% Speed(reviews/sec):150.8 #Correct:3751 #Trained:7501 Training Accuracy:50.0%
# Progress:37.6% Speed(reviews/sec):150.3 #Correct:4514 #Trained:9028 Training Accuracy:50.0%
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-76-ad0ddebea879> in <module>()
# ----> 1 mlp.train(reviews[:-1000],labels[:-1000])
#
# <ipython-input-73-132cc2d9bc28> in train(self, training_reviews, training_labels)
#     134
#     135             # Hidden layer
# --> 136             layer_1 = self.layer_0.dot(self.weights_0_1)
#     137
#     138             # Output layer
#
# KeyboardInterrupt:

# %% [markdown]
# That most likely didn't train very well. Part of the reason may be because the learning rate is too high. Run the following cell to recreate the network with a smaller learning rate, `0.01`, and then train the new network.

# %%
mlp = SentimentNetwork(reviews[:-1000],labels[:-1000], learning_rate=0.01)
mlp.train(reviews[:-1000],labels[:-1000])
# Out:
# Progress:0.0% Speed(reviews/sec):0.0 #Correct:1 #Trained:1 Training Accuracy:100.%
# Progress:10.4% Speed(reviews/sec):135.7 #Correct:1248 #Trained:2501 Training Accuracy:49.9%
# Progress:20.8% Speed(reviews/sec):136.1 #Correct:2498 #Trained:5001 Training Accuracy:49.9%
# Progress:27.2% Speed(reviews/sec):134.9 #Correct:3270 #Trained:6545 Training Accuracy:49.9%
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-77-6f725220b326> in <module>()
#       1 mlp = SentimentNetwork(reviews[:-1000],labels[:-1000], learning_rate=0.01)
# ----> 2 mlp.train(reviews[:-1000],labels[:-1000])
#
# <ipython-input-73-132cc2d9bc28> in train(self, training_reviews, training_labels)
#     152             # Update the weights
#     153             self.weights_1_2 -= layer_1.T.dot(layer_2_delta) * self.learning_rate # update hidden-to-output weights with gradient descent step
# --> 154             self.weights_0_1 -= self.layer_0.T.dot(layer_1_delta) * self.learning_rate # update input-to-hidden weights with gradient descent step
#     155
#     156             # Keep track of correct predictions.
#
# KeyboardInterrupt:

# %% [markdown]
# That probably wasn't much different. Run the following cell to recreate the network one more time with an even smaller learning rate, `0.001`, and then train the new network.

# %%
mlp = SentimentNetwork(reviews[:-1000],labels[:-1000], learning_rate=0.001)
mlp.train(reviews[:-1000],labels[:-1000])
# Out:
# Progress:0.0% Speed(reviews/sec):0.0 #Correct:1 #Trained:1 Training Accuracy:100.%
# Progress:10.4% Speed(reviews/sec):142.0 #Correct:1276 #Trained:2501 Training Accuracy:51.0%
# Progress:20.8% Speed(reviews/sec):138.9 #Correct:2628 #Trained:5001 Training Accuracy:52.5%
# Progress:31.2% Speed(reviews/sec):135.6 #Correct:4069 #Trained:7501 Training Accuracy:54.2%
# Progress:41.6% Speed(reviews/sec):133.3 #Correct:5594 #Trained:10001 Training Accuracy:55.9%
# Progress:52.0% Speed(reviews/sec):132.1 #Correct:7192 #Trained:12501 Training Accuracy:57.5%
# Progress:62.5% Speed(reviews/sec):131.2 #Correct:8735 #Trained:15001 Training Accuracy:58.2%
# Progress:72.9% Speed(reviews/sec):130.4 #Correct:10366 #Trained:17501 Training Accuracy:59.2%
# Progress:83.3% Speed(reviews/sec):129.8 #Correct:12068 #Trained:20001 Training Accuracy:60.3%
# Progress:93.7% Speed(reviews/sec):129.4 #Correct:13753 #Trained:22501 Training Accuracy:61.1%
# Progress:99.9% Speed(reviews/sec):129.1 #Correct:14784 #Trained:24000 Training Accuracy:61.6%

# %% [markdown]
# With a learning rate of `0.001`, the network should finall have started to improve during training. It's still not very good, but it shows that this solution has potential. We will improve it in the next lesson.

# %% [markdown]
# # End of Project 3.
# ## Watch the next video to see Andrew's solution, then continue on to the next lesson.

# %% [markdown]
# # Understanding Neural Noise<a id='lesson_4'></a>
#
# The following cells include includes the code Andrew shows in the next video. We've included it here so you can run the cells along with the video without having to type in everything.

# %%
from IPython.display import Image
Image(filename='sentiment_network.png')

# %%
def update_input_layer(review):
    
    global layer_0
    
    # clear out previous state, reset the layer to be all 0s
    layer_0 *= 0
    for word in review.split(" "):
        layer_0[0][word2index[word]] += 1

update_input_layer(reviews[0])

# %%
layer_0
# Out:
# array([[ 18.,   0.,   0., ...,   0.,   0.,   0.]])

# %%
review_counter = Counter()

# %%
for word in reviews[0].split(" "):
    review_counter[word] += 1

# %%
review_counter.most_common()
# Out:
# [('.', 27),
#  ('', 18),
#  ('the', 9),
#  ('to', 6),
#  ('i', 5),
#  ('high', 5),
#  ('bromwell', 4),
#  ('teachers', 4),
#  ('is', 4),
#  ('that', 4),
#  ('a', 4),
#  ('of', 4),
#  ('me', 2),
#  ('my', 2),
#  ('student', 2),
#  ('school', 2),
#  ('as', 2),
#  ('their', 2),
#  ('in', 2),
#  ('students', 2),
#  ('at', 2),
#  ('it', 2),
#  ('survive', 1),
#  ('line', 1),
#  ('some', 1),
#  ('time', 1),
#  ('m', 1),
#  ('welcome', 1),
#  ('classic', 1),
#  ('see', 1),
#  ('through', 1),
#  ('and', 1),
#  ('same', 1),
#  ('schools', 1),
#  ('pettiness', 1),
#  ('life', 1),
#  ('which', 1),
#  ('down', 1),
#  ('situation', 1),
#  ('immediately', 1),
#  ('closer', 1),
#  ('believe', 1),
#  ('saw', 1),
#  ('scramble', 1),
#  ('ran', 1),
#  ('sack', 1),
#  ('much', 1),
#  ('one', 1),
#  ('what', 1),
#  ('s', 1),
#  ('when', 1),
#  ('remind', 1),
#  ('tried', 1),
#  ('such', 1),
#  ('can', 1),
#  ('your', 1),
#  ('think', 1),
#  ('age', 1),
#  ('far', 1),
#  ('satire', 1),
#  ('right', 1),
#  ('insightful', 1),
#  ('pathetic', 1),
#  ('who', 1),
#  ('many', 1),
#  ('pity', 1),
#  ('recalled', 1),
#  ('cartoon', 1),
#  ('pomp', 1),
#  ('expect', 1),
#  ('fetched', 1),
#  ('about', 1),
#  ('repeatedly', 1),
#  ('inspector', 1),
#  ('teaching', 1),
#  ('here', 1),
#  ('lead', 1),
#  ('reality', 1),
#  ('adults', 1),
#  ('burn', 1),
#  ('t', 1),
#  ('all', 1),
#  ('years', 1),
#  ('comedy', 1),
#  ('than', 1),
#  ('programs', 1),
#  ('profession', 1),
#  ('knew', 1),
#  ('other', 1),
#  ('financially', 1),
#  ('isn', 1),
#  ('episode', 1),
#  ('whole', 1)]

# %% [markdown]
# # Project 4: Reducing Noise in Our Input Data<a id='project_4'></a>
#
# **TODO:** Attempt to reduce the noise in the input data like Andrew did in the previous video. Specifically, do the following:
# * Copy the `SentimentNetwork` class you created earlier into the following cell.
# * Modify `update_input_layer` so it does not count how many times each word is used, but rather just stores whether or not a word was used.

# %%
# TODO: -Copy the SentimentNetwork class from Projet 3 lesson
#       -Modify it to reduce noise, like in the video 

import time
import sys
import numpy as np

# Encapsulate our neural network in a class
class SentimentNetwork:
    def __init__(self, reviews,labels,hidden_nodes = 10, learning_rate = 0.1):
        """Create a SentimenNetwork with the given settings
        Args:
            reviews(list) - List of reviews used for training
            labels(list) - List of POSITIVE/NEGATIVE labels associated with the given reviews
            hidden_nodes(int) - Number of nodes to create in the hidden layer
            learning_rate(float) - Learning rate to use while training
        
        """
        # Assign a seed to our random number generator to ensure we get
        # reproducable results during development 
        np.random.seed(1)

        # process the reviews and their associated labels so that everything
        # is ready for training
        self.pre_process_data(reviews, labels)
        
        # Build the network to have the number of hidden nodes and the learning rate that
        # were passed into this initializer. Make the same number of input nodes as
        # there are vocabulary words and create a single output node.
        self.init_network(len(self.review_vocab),hidden_nodes, 1, learning_rate)

    def pre_process_data(self, reviews, labels):
        
        # populate review_vocab with all of the words in the given reviews
        review_vocab = set()
        for review in reviews:
            for word in review.split(" "):
                review_vocab.add(word)

        # Convert the vocabulary set to a list so we can access words via indices
        self.review_vocab = list(review_vocab)
        
        # populate label_vocab with all of the words in the given labels.
        label_vocab = set()
        for label in labels:
            label_vocab.add(label)
        
        # Convert the label vocabulary set to a list so we can access labels via indices
        self.label_vocab = list(label_vocab)
        
        # Store the sizes of the review and label vocabularies.
        self.review_vocab_size = len(self.review_vocab)
        self.label_vocab_size = len(self.label_vocab)
        
        # Create a dictionary of words in the vocabulary mapped to index positions
        self.word2index = {}
        for i, word in enumerate(self.review_vocab):
            self.word2index[word] = i
        
        # Create a dictionary of labels mapped to index positions
        self.label2index = {}
        for i, label in enumerate(self.label_vocab):
            self.label2index[label] = i
        
    def init_network(self, input_nodes, hidden_nodes, output_nodes, learning_rate):
        # Set number of nodes in input, hidden and output layers.
        self.input_nodes = input_nodes
        self.hidden_nodes = hidden_nodes
        self.output_nodes = output_nodes

        # Store the learning rate
        self.learning_rate = learning_rate

        # Initialize weights

        # These are the weights between the input layer and the hidden layer.
        self.weights_0_1 = np.zeros((self.input_nodes,self.hidden_nodes))
    
        # These are the weights between the hidden layer and the output layer.
        self.weights_1_2 = np.random.normal(0.0, self.output_nodes**-0.5, 
                                                (self.hidden_nodes, self.output_nodes))
        
        # The input layer, a two-dimensional matrix with shape 1 x input_nodes
        self.layer_0 = np.zeros((1,input_nodes))
    
        
    def update_input_layer(self,review):

        # clear out previous state, reset the layer to be all 0s
        self.layer_0 *= 0
        
        for word in review.split(" "):
            # NOTE: This if-check was not in the version of this method created in Project 2,
            #       and it appears in Andrew's Project 3 solution without explanation. 
            #       It simply ensures the word is actually a key in word2index before
            #       accessing it, which is important because accessing an invalid key
            #       with raise an exception in Python. This allows us to ignore unknown
            #       words encountered in new reviews.
            if(word in self.word2index.keys()):
                ## New for Project 4: changed to set to 1 instead of add 1
                self.layer_0[0][self.word2index[word]] = 1
                
    def get_target_for_label(self,label):
        if(label == 'POSITIVE'):
            return 1
        else:
            return 0
        
    def sigmoid(self,x):
        return 1 / (1 + np.exp(-x))
    
    def sigmoid_output_2_derivative(self,output):
        return output * (1 - output)
    
    def train(self, training_reviews, training_labels):
        
        # make sure out we have a matching number of reviews and labels
        assert(len(training_reviews) == len(training_labels))
        
        # Keep track of correct predictions to display accuracy during training 
        correct_so_far = 0

        # Remember when we started for printing time statistics
        start = time.time()
        
        # loop through all the given reviews and run a forward and backward pass,
        # updating weights for every item
        for i in range(len(training_reviews)):
            
            # Get the next review and its correct label
            review = training_reviews[i]
            label = training_labels[i]
            
            #### Implement the forward pass here ####
            ### Forward pass ###

            # Input Layer
            self.update_input_layer(review)

            # Hidden layer
            layer_1 = self.layer_0.dot(self.weights_0_1)

            # Output layer
            layer_2 = self.sigmoid(layer_1.dot(self.weights_1_2))
            
            #### Implement the backward pass here ####
            ### Backward pass ###

            # Output error
            layer_2_error = layer_2 - self.get_target_for_label(label) # Output layer error is the difference between desired target and actual output.
            layer_2_delta = layer_2_error * self.sigmoid_output_2_derivative(layer_2)

            # Backpropagated error
            layer_1_error = layer_2_delta.dot(self.weights_1_2.T) # errors propagated to the hidden layer
            layer_1_delta = layer_1_error # hidden layer gradients - no nonlinearity so it's the same as the error

            # Update the weights
            self.weights_1_2 -= layer_1.T.dot(layer_2_delta) * self.learning_rate # update hidden-to-output weights with gradient descent step
            self.weights_0_1 -= self.layer_0.T.dot(layer_1_delta) * self.learning_rate # update input-to-hidden weights with gradient descent step

            # Keep track of correct predictions.
            if(layer_2 >= 0.5 and label == 'POSITIVE'):
                correct_so_far += 1
            elif(layer_2 < 0.5 and label == 'NEGATIVE'):
                correct_so_far += 1
            
            # For debug purposes, print out our prediction accuracy and speed 
            # throughout the training process. 
            elapsed_time = float(time.time() - start)
            reviews_per_second = i / elapsed_time if elapsed_time > 0 else 0
            
            sys.stdout.write("\rProgress:" + str(100 * i/float(len(training_reviews)))[:4] \
                             + "% Speed(reviews/sec):" + str(reviews_per_second)[0:5] \
                             + " #Correct:" + str(correct_so_far) + " #Trained:" + str(i+1) \
                             + " Training Accuracy:" + str(correct_so_far * 100 / float(i+1))[:4] + "%")
            if(i % 2500 == 0):
                print("")
    
    def test(self, testing_reviews, testing_labels):
        """
        Attempts to predict the labels for the given testing_reviews,
        and uses the test_labels to calculate the accuracy of those predictions.
        """
        
        # keep track of how many correct predictions we make
        correct = 0

        # we'll time how many predictions per second we make
        start = time.time()

        # Loop through each of the given reviews and call run to predict
        # its label. 
        for i in range(len(testing_reviews)):
            pred = self.run(testing_reviews[i])
            if(pred == testing_labels[i]):
                correct += 1
            
            # For debug purposes, print out our prediction accuracy and speed 
            # throughout the prediction process. 

            elapsed_time = float(time.time() - start)
            reviews_per_second = i / elapsed_time if elapsed_time > 0 else 0
            
            sys.stdout.write("\rProgress:" + str(100 * i/float(len(testing_reviews)))[:4] \
                             + "% Speed(reviews/sec):" + str(reviews_per_second)[0:5] \
                             + " #Correct:" + str(correct) + " #Tested:" + str(i+1) \
                             + " Testing Accuracy:" + str(correct * 100 / float(i+1))[:4] + "%")
    
    def run(self, review):
        """
        Returns a POSITIVE or NEGATIVE prediction for the given review.
        """
        # Run a forward pass through the network, like in the "train" function.
        
        # Input Layer
        self.update_input_layer(review.lower())

        # Hidden layer
        layer_1 = self.layer_0.dot(self.weights_0_1)

        # Output layer
        layer_2 = self.sigmoid(layer_1.dot(self.weights_1_2))
        
        # Return POSITIVE for values above greater-than-or-equal-to 0.5 in the output layer;
        # return NEGATIVE for other values
        if(layer_2[0] >= 0.5):
            return "POSITIVE"
        else:
            return "NEGATIVE"

# %% [markdown]
# Run the following cell to recreate the network and train it. Notice we've gone back to the higher learning rate of `0.1`.

# %%
mlp = SentimentNetwork(reviews[:-1000],labels[:-1000], learning_rate=0.1)
mlp.train(reviews[:-1000],labels[:-1000])
# Out:
# Progress:0.0% Speed(reviews/sec):0.0 #Correct:1 #Trained:1 Training Accuracy:100.%
# Progress:10.4% Speed(reviews/sec):127.9 #Correct:1805 #Trained:2501 Training Accuracy:72.1%
# Progress:20.8% Speed(reviews/sec):129.7 #Correct:3798 #Trained:5001 Training Accuracy:75.9%
# Progress:31.2% Speed(reviews/sec):130.3 #Correct:5887 #Trained:7501 Training Accuracy:78.4%
# Progress:41.6% Speed(reviews/sec):130.0 #Correct:8023 #Trained:10001 Training Accuracy:80.2%
# Progress:52.0% Speed(reviews/sec):129.6 #Correct:10148 #Trained:12501 Training Accuracy:81.1%
# Progress:62.5% Speed(reviews/sec):129.4 #Correct:12288 #Trained:15001 Training Accuracy:81.9%
# Progress:72.9% Speed(reviews/sec):129.3 #Correct:14408 #Trained:17501 Training Accuracy:82.3%
# Progress:83.3% Speed(reviews/sec):129.7 #Correct:16587 #Trained:20001 Training Accuracy:82.9%
# Progress:93.7% Speed(reviews/sec):129.5 #Correct:18771 #Trained:22501 Training Accuracy:83.4%
# Progress:99.9% Speed(reviews/sec):129.2 #Correct:20090 #Trained:24000 Training Accuracy:83.7%

# %% [markdown]
# That should have trained much better than the earlier attempts. It's still not wonderful, but it should have improved dramatically. Run the following cell to test your model with 1000 predictions.

# %%
mlp.test(reviews[-1000:],labels[-1000:])

# %% [markdown]
# # End of Project 4.
# ## Andrew's solution was actually in the previous video, so rewatch that video if you had any problems with that project. Then continue on to the next lesson.
# # Analyzing Inefficiencies in our Network<a id='lesson_5'></a>
# The following cells include the code Andrew shows in the next video. We've included it here so you can run the cells along with the video without having to type in everything.

# %%
Image(filename='sentiment_network_sparse.png')

# %%
layer_0 = np.zeros(10)

# %%
layer_0

# %%
layer_0[4] = 1
layer_0[9] = 1

# %%
layer_0

# %%
weights_0_1 = np.random.randn(10,5)

# %%
layer_0.dot(weights_0_1)

# %%
indices = [4,9]

# %%
layer_1 = np.zeros(5)

# %%
for index in indices:
    layer_1 += (1 * weights_0_1[index])

# %%
layer_1

# %%
Image(filename='sentiment_network_sparse_2.png')

# %%
layer_1 = np.zeros(5)

# %%
for index in indices:
    layer_1 += (weights_0_1[index])

# %%
layer_1

# %% [markdown]
# # Project 5: Making our Network More Efficient<a id='project_5'></a>
# **TODO:** Make the `SentimentNetwork` class more efficient by eliminating unnecessary multiplications and additions that occur during forward and backward propagation. To do that, you can do the following:
# * Copy the `SentimentNetwork` class from the previous project into the following cell.
# * Remove the `update_input_layer` function - you will not need it in this version.
# * Modify `init_network`:
# >* You no longer need a separate input layer, so remove any mention of `self.layer_0`
# >* You will be dealing with the old hidden layer more directly, so create `self.layer_1`, a two-dimensional matrix with shape 1 x hidden_nodes, with all values initialized to zero
# * Modify `train`:
# >* Change the name of the input parameter `training_reviews` to `training_reviews_raw`. This will help with the next step.
# >* At the beginning of the function, you'll want to preprocess your reviews to convert them to a list of indices (from `word2index`) that are actually used in the review. This is equivalent to what you saw in the video when Andrew set specific indices to 1. Your code should create a local `list` variable named `training_reviews` that should contain a `list` for each review in `training_reviews_raw`. Those lists should contain the indices for words found in the review.
# >* Remove call to `update_input_layer`
# >* Use `self`'s  `layer_1` instead of a local `layer_1` object.
# >* In the forward pass, replace the code that updates `layer_1` with new logic that only adds the weights for the indices used in the review.
# >* When updating `weights_0_1`, only update the individual weights that were used in the forward pass.
# * Modify `run`:
# >* Remove call to `update_input_layer`
# >* Use `self`'s  `layer_1` instead of a local `layer_1` object.
# >* Much like you did in `train`, you will need to pre-process the `review` so you can work with word indices, then update `layer_1` by adding weights for the indices used in the review.

# %%
# TODO: -Copy the SentimentNetwork class from Project 4 lesson
#       -Modify it according to the above instructions

# %% [markdown]
# Run the following cell to recreate the network and train it once again.

# %%
mlp = SentimentNetwork(reviews[:-1000],labels[:-1000], learning_rate=0.1)
mlp.train(reviews[:-1000],labels[:-1000])

# %% [markdown]
# That should have trained much better than the earlier attempts. Run the following cell to test your model with 1000 predictions.

# %%
mlp.test(reviews[-1000:],labels[-1000:])

# %% [markdown]
# # End of Project 5.
# ## Watch the next video to see Andrew's solution, then continue on to the next lesson.
# # Further Noise Reduction<a id='lesson_6'></a>

# %%
Image(filename='sentiment_network_sparse_2.png')

# %%
# words most frequently seen in a review with a "POSITIVE" label
pos_neg_ratios.most_common()

# %%
# words most frequently seen in a review with a "NEGATIVE" label
list(reversed(pos_neg_ratios.most_common()))[0:30]

# %%
from bokeh.models import ColumnDataSource, LabelSet
from bokeh.plotting import figure, show, output_file
from bokeh.io import output_notebook
output_notebook()

# %%
hist, edges = np.histogram(list(map(lambda x:x[1],pos_neg_ratios.most_common())), density=True, bins=100, normed=True)

p = figure(tools="pan,wheel_zoom,reset,save",
           toolbar_location="above",
           title="Word Positive/Negative Affinity Distribution")
p.quad(top=hist, bottom=0, left=edges[:-1], right=edges[1:], line_color="#555555")
show(p)

# %%
frequency_frequency = Counter()

for word, cnt in total_counts.most_common():
    frequency_frequency[cnt] += 1

# %%
hist, edges = np.histogram(list(map(lambda x:x[1],frequency_frequency.most_common())), density=True, bins=100, normed=True)

p = figure(tools="pan,wheel_zoom,reset,save",
           toolbar_location="above",
           title="The frequency distribution of the words in our corpus")
p.quad(top=hist, bottom=0, left=edges[:-1], right=edges[1:], line_color="#555555")
show(p)

# %% [markdown]
# # Project 6: Reducing Noise by Strategically Reducing the Vocabulary<a id='project_6'></a>
#
# **TODO:** Improve `SentimentNetwork`'s performance by reducing more noise in the vocabulary. Specifically, do the following:
# * Copy the `SentimentNetwork` class from the previous project into the following cell.
# * Modify `pre_process_data`:
# >* Add two additional parameters: `min_count` and `polarity_cutoff`
# >* Calculate the positive-to-negative ratios of words used in the reviews. (You can use code you've written elsewhere in the notebook, but we are moving it into the class like we did with other helper code earlier.)
# >* Andrew's solution only calculates a postive-to-negative ratio for words that occur at least 50 times. This keeps the network from attributing too much sentiment to rarer words. You can choose to add this to your solution if you would like.
# >* Change so words are only added to the vocabulary if they occur in the vocabulary more than `min_count` times.
# >* Change so words are only added to the vocabulary if the absolute value of their postive-to-negative ratio is at least `polarity_cutoff`
# * Modify `__init__`:
# >* Add the same two parameters (`min_count` and `polarity_cutoff`) and use them when you call `pre_process_data`

# %%
# TODO: -Copy the SentimentNetwork class from Project 5 lesson
#       -Modify it according to the above instructions

# %% [markdown]
# Run the following cell to train your network with a small polarity cutoff.

# %%
mlp = SentimentNetwork(reviews[:-1000],labels[:-1000],min_count=20,polarity_cutoff=0.05,learning_rate=0.01)
mlp.train(reviews[:-1000],labels[:-1000])

# %% [markdown]
# And run the following cell to test it's performance. It should be

# %%
mlp.test(reviews[-1000:],labels[-1000:])

# %% [markdown]
# Run the following cell to train your network with a much larger polarity cutoff.

# %%
mlp = SentimentNetwork(reviews[:-1000],labels[:-1000],min_count=20,polarity_cutoff=0.8,learning_rate=0.01)
mlp.train(reviews[:-1000],labels[:-1000])

# %% [markdown]
# And run the following cell to test it's performance.

# %%
mlp.test(reviews[-1000:],labels[-1000:])

# %% [markdown]
# # End of Project 6.
# ## Watch the next video to see Andrew's solution, then continue on to the next lesson.

# %% [markdown]
# # Analysis: What's Going on in the Weights?<a id='lesson_7'></a>

# %%
mlp_full = SentimentNetwork(reviews[:-1000],labels[:-1000],min_count=0,polarity_cutoff=0,learning_rate=0.01)

# %%
mlp_full.train(reviews[:-1000],labels[:-1000])

# %%
Image(filename='sentiment_network_sparse.png')

# %%
def get_most_similar_words(focus = "horrible"):
    most_similar = Counter()

    for word in mlp_full.word2index.keys():
        most_similar[word] = np.dot(mlp_full.weights_0_1[mlp_full.word2index[word]],mlp_full.weights_0_1[mlp_full.word2index[focus]])
    
    return most_similar.most_common()

# %%
get_most_similar_words("excellent")

# %%
get_most_similar_words("terrible")

# %%
import matplotlib.colors as colors

words_to_visualize = list()
for word, ratio in pos_neg_ratios.most_common(500):
    if(word in mlp_full.word2index.keys()):
        words_to_visualize.append(word)
    
for word, ratio in list(reversed(pos_neg_ratios.most_common()))[0:500]:
    if(word in mlp_full.word2index.keys()):
        words_to_visualize.append(word)

# %%
pos = 0
neg = 0

colors_list = list()
vectors_list = list()
for word in words_to_visualize:
    if word in pos_neg_ratios.keys():
        vectors_list.append(mlp_full.weights_0_1[mlp_full.word2index[word]])
        if(pos_neg_ratios[word] > 0):
            pos+=1
            colors_list.append("#00ff00")
        else:
            neg+=1
            colors_list.append("#000000")

# %%
from sklearn.manifold import TSNE
tsne = TSNE(n_components=2, random_state=0)
words_top_ted_tsne = tsne.fit_transform(vectors_list)

# %%
p = figure(tools="pan,wheel_zoom,reset,save",
           toolbar_location="above",
           title="vector T-SNE for most polarized words")

source = ColumnDataSource(data=dict(x1=words_top_ted_tsne[:,0],
                                    x2=words_top_ted_tsne[:,1],
                                    names=words_to_visualize,
                                    color=colors_list))

p.scatter(x="x1", y="x2", size=8, source=source, fill_color="color")

word_labels = LabelSet(x="x1", y="x2", text="names", y_offset=6,
                  text_font_size="8pt", text_color="#555555",
                  source=source, text_align='center')
p.add_layout(word_labels)

show(p)

# green indicates positive words, black indicates negative words
